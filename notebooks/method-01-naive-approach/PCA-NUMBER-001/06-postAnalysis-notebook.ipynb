# %% [markdown]
# # 06-post-analysis
#
# How can we verify if the trained models are correct in their predictions?
#
# One way is to verify against known candidates.

# %%
import sys
sys.path.insert(0, "../")

import pandas as pd
from pathlib import Path

data_dir = Path.cwd().parent.parent.parent / "data"
models_dir = Path.cwd().parent.parent.parent / "models" 

print("Current data directory {}".format(data_dir))
# Out:
# Current data directory /home/oliver/Dokumenter/masterprosjekt/predicting-solid-state-qubit-candidates/data

# %%
known_candidates = ["C", "Si", "SiGe", "AlN", "GaN",
                   "AlP", "GaP", "AlAs", "ZnO", "ZnS", "ZnSe", "ZnTe", "CdS"]
QD_2D_candidates = ["BN", "MoS2", "WSe2", #2D
                    "LnAs" #QD
                   ]

# %%
InsertApproach = "01-naive-approach"
numberOfPrincipalComponents = 1

# %% [markdown]
# ## Training set
# How many entries in our training set consists of known candidates?

# %%
trainingSet   = pd.read_pickle(data_dir / InsertApproach / "processed" / "trainingSet.pkl")

# %%
trainingSet[["full_formula", "pretty_formula", "candidate"]][trainingSet["pretty_formula"].isin(known_candidates)]
# Out:
#      full_formula pretty_formula  candidate
# 3              C8              C        1.0
# 4              C4              C        1.0
# 5              C2              C        1.0
# 11            Si2             Si        1.0
# 12            Si4             Si        1.0
# 13             C2              C        1.0
# 29          Al2N2            AlN        0.0
# 40          Ga2N2            GaN        0.0
# 50         Zn1Se1           ZnSe        1.0
# 83          Zn1O1            ZnO        1.0
# 90         Zn1Te1           ZnTe        1.0
# 92          Zn1O1            ZnO        1.0
# 294         Al2P2            AlP        0.0
# 295        Al2As2           AlAs        0.0
# 296         Ga2P2            GaP        0.0
# 324         Zn1S1            ZnS        1.0
# 359         Zn1O1            ZnO        1.0
# 378          Si34             Si        1.0
# 950            C4              C        1.0
# 952            C8              C        1.0
# 957           C14              C        1.0
# 961        Zn2Se2           ZnSe        1.0
# 970            C8              C        1.0
# 1072           C8              C        1.0
# 1073          C12              C        1.0
# 1078          C16              C        1.0
# 1096          C60              C        1.0
# 1173          C60              C        1.0
# 1223          C60              C        1.0
# 1228         C140              C        1.0
# 1266         Si46             Si        1.0
# 1275          Si4             Si        1.0
# 1280           C4              C        1.0
# 1370           C8              C        1.0
# 1390           C8              C        1.0
# 1397         Si12             Si        1.0
# 1404          C12              C        1.0
# 1407          C12              C        1.0
# 1462          C16              C        1.0
# 1517         C240              C        1.0
# 1519         Si40             Si        1.0
# 1545         Si82             Si        1.0
# 1554         Si41             Si        1.0
# 1560        Si232             Si        1.0
# 1580         Si58             Si        1.0
# 1588          C48              C        1.0
# 1591         Si68             Si        1.0
# 1596         Si46             Si        1.0
# 1610          C20              C        1.0

# %%
trainingSet[["full_formula", "pretty_formula", "candidate"]][trainingSet["pretty_formula"].isin(QD_2D_candidates)]
# Out:
#      full_formula pretty_formula  candidate
# 20           B4N4             BN        0.0
# 66           B4N4             BN        0.0
# 73          W2Se4           WSe2        1.0
# 110          B2N2             BN        0.0
# 117         Mo2S4           MoS2        1.0
# 1238         B1N1             BN        0.0
# 1312        Mo2S4           MoS2        1.0
# 1360         B3N3             BN        0.0

# %% [markdown]
# ## Test set
# How many entries in our test set consists of known candidates?

# %%
Summary = pd.read_pickle(models_dir / InsertApproach /  "summary" / Path("PCA-" + str(numberOfPrincipalComponents) + "-" + "summary.pkl"))
Summary.shape
# Out:
# (23605, 9)

# %%
Summary[Summary["pretty_formula"].isin(known_candidates)]
# Out:
#       material_id full_formula pretty_formula  LOG   LOG Prob  RF    RF Prob  \
# 1685       mp-370        Cd1S1            CdS   1.0  0.650111  0.0  0.373975
# 1687       mp-380       Zn2Se2           ZnSe   1.0  0.685966  1.0  0.837215
# 1724       mp-672        Cd2S2            CdS   1.0  0.694004  1.0  0.849556
# 1742       mp-830        Ga1N1            GaN   1.0  0.741506  1.0  0.855064
# 1803      mp-1330        Al1N1            AlN   1.0  0.750884  1.0  0.855064
# ...           ...          ...            ...   ...       ...  ...       ...
# 24249  mp-1201781      Zn18S18            ZnS   1.0  0.719805  1.0  0.855064
# 24311  mp-1202023      Zn18S18            ZnS   1.0  0.722828  1.0  0.855064
# 24352  mp-1202182      Zn18S18            ZnS   1.0  0.722563  1.0  0.855064
# 24556  mp-1202959      Zn18S18            ZnS   1.0  0.722237  1.0  0.855064
# 24848  mp-1204046        Si106             Si   1.0  0.762373  1.0  0.855064
#
#        GB    GB Prob
# 1685   0.0  0.282534
# 1687   1.0  0.717306
# 1724   1.0  0.717306
# 1742   1.0  0.847745
# 1803   1.0  0.847745
# ...    ...       ...
# 24249  1.0  0.783040
# 24311  1.0  0.783040
# 24352  1.0  0.783040
# 24556  1.0  0.783040
# 24848  1.0  0.847745
#
# [106 rows x 9 columns]

# %%
Summary[Summary["pretty_formula"].isin(QD_2D_candidates)]
# Out:
#       material_id full_formula pretty_formula  LOG   LOG Prob  RF    RF Prob  \
# 1762       mp-984         B2N2             BN   1.0  0.835261  1.0  0.855064
# 1819      mp-1434        Mo1S2           MoS2   1.0  0.754634  1.0  0.855064
# 1840      mp-1639         B1N1             BN   1.0  0.833914  1.0  0.855064
# 3384      mp-7991         B2N2             BN   1.0  0.844307  1.0  0.855064
# 4439     mp-13151         B4N4             BN   1.0  0.841676  1.0  0.855064
# 15144   mp-569655         B4N4             BN   1.0  0.847931  1.0  0.855064
# 15929   mp-604884         B2N2             BN   1.0  0.842349  1.0  0.855064
# 16269   mp-629015         B2N2             BN   1.0  0.837123  1.0  0.855064
# 16647   mp-644751         B4N4             BN   1.0  0.843976  1.0  0.855064
# 19883  mp-1060281         B1N1             BN   1.0  0.804452  1.0  0.855064
#
#        GB    GB Prob
# 1762   1.0  0.757796
# 1819   1.0  0.847745
# 1840   1.0  0.891151
# 3384   1.0  0.872652
# 4439   1.0  0.872652
# 15144  1.0  0.890291
# 15929  1.0  0.872652
# 16269  1.0  0.872652
# 16647  1.0  0.872652
# 19883  1.0  0.930478

# %% [markdown]
# ## How many entries does the models agree on?

# %%
Summary[(Summary["RF "] == 1) & 
        (Summary["GB "] == 1) & 
        (Summary["LOG "] == 1)]
# Out:
#       material_id full_formula pretty_formula  LOG   LOG Prob  RF    RF Prob  \
# 1649    mvc-12905        Fe4O8           FeO2   1.0  0.819134  1.0  0.855064
# 1650        mp-25           N8             N2   1.0  0.813646  1.0  0.855064
# 1651       mp-111          Ne1             Ne   1.0  0.722415  1.0  0.855064
# 1652       mp-118          P24              P   1.0  0.787397  1.0  0.855064
# 1653       mp-154           N8             N2   1.0  0.814762  1.0  0.855064
# ...           ...          ...            ...   ...       ...  ...       ...
# 25249  mp-1539137     Rb1Cr5S8        RbCr5S8   1.0  0.768488  1.0  0.855064
# 25250  mp-1541522      Bi2P2O8          BiPO4   1.0  0.802311  1.0  0.855064
# 25251  mp-1541714    Cs3As2Cl9      Cs3As2Cl9   1.0  0.741420  1.0  0.855064
# 25252  mp-1542038    Cs2Sn2Se6        CsSnSe3   1.0  0.721005  1.0  0.855064
# 25253  mp-1542939   Ba1Mo1P2O8     BaMo(PO4)2   1.0  0.830093  1.0  0.855064
#
#        GB    GB Prob
# 1649   1.0  0.882531
# 1650   1.0  0.882531
# 1651   1.0  0.783040
# 1652   1.0  0.882551
# 1653   1.0  0.882531
# ...    ...       ...
# 25249  1.0  0.847745
# 25250  1.0  0.880991
# 25251  1.0  0.847745
# 25252  1.0  0.783040
# 25253  1.0  0.883340
#
# [21450 rows x 9 columns]
