# %% [markdown]
# # 06-post-analysis
#
# How can we verify if the trained models are correct in their predictions?
#
# One way is to verify against known candidates.

# %%
import sys
sys.path.insert(0, "../")

import pandas as pd
from pathlib import Path

data_dir = Path.cwd().parent.parent / "data"
models_dir = Path.cwd().parent.parent / "models" 

print("Current data directory {}".format(data_dir))
# Out:
# Current data directory /home/oliver/Dokumenter/masterprosjekt/predicting-solid-state-qubit-candidates/data

# %%
known_candidates = ["C", "Si", "SiGe", "AlN", "GaN",
                   "AlP", "GaP", "AlAs", "ZnO", "ZnS", "ZnSe", "ZnTe", "CdS"]
QD_2D_candidates = ["BN", "MoS2", "WSe2", #2D
                    "LnAs" #QD
                   ]

# %%
InsertApproach = "01-naive-approach"

# %% [markdown]
# ## Training set
# How many entries in our training set consists of known candidates?

# %%
trainingSet   = pd.read_pickle(data_dir / InsertApproach / "processed" / "trainingSet.pkl")

# %%
trainingSet[["full_formula", "pretty_formula", "candidate"]][trainingSet["pretty_formula"].isin(known_candidates)]
# Out:
#      full_formula pretty_formula  candidate
# 3              C8              C        1.0
# 4              C4              C        1.0
# 5              C2              C        1.0
# 11            Si2             Si        1.0
# 12            Si4             Si        1.0
# 13             C2              C        1.0
# 29          Al2N2            AlN        0.0
# 40          Ga2N2            GaN        0.0
# 50         Zn1Se1           ZnSe        1.0
# 83          Zn1O1            ZnO        1.0
# 90         Zn1Te1           ZnTe        1.0
# 92          Zn1O1            ZnO        1.0
# 294         Al2P2            AlP        0.0
# 295        Al2As2           AlAs        0.0
# 296         Ga2P2            GaP        0.0
# 324         Zn1S1            ZnS        1.0
# 359         Zn1O1            ZnO        1.0
# 378          Si34             Si        1.0
# 951            C4              C        1.0
# 953            C8              C        1.0
# 958           C14              C        1.0
# 962        Zn2Se2           ZnSe        1.0
# 971            C8              C        1.0
# 1073           C8              C        1.0
# 1074          C12              C        1.0
# 1079          C16              C        1.0
# 1097          C60              C        1.0
# 1174          C60              C        1.0
# 1224          C60              C        1.0
# 1229         C140              C        1.0
# 1267         Si46             Si        1.0
# 1276          Si4             Si        1.0
# 1281           C4              C        1.0
# 1371           C8              C        1.0
# 1391           C8              C        1.0
# 1398         Si12             Si        1.0
# 1405          C12              C        1.0
# 1408          C12              C        1.0
# 1463          C16              C        1.0
# 1518         C240              C        1.0
# 1520         Si40             Si        1.0
# 1546         Si82             Si        1.0
# 1555         Si41             Si        1.0
# 1561        Si232             Si        1.0
# 1581         Si58             Si        1.0
# 1589          C48              C        1.0
# 1592         Si68             Si        1.0
# 1597         Si46             Si        1.0
# 1611          C20              C        1.0

# %%
trainingSet[["full_formula", "pretty_formula", "candidate"]][trainingSet["pretty_formula"].isin(QD_2D_candidates)]
# Out:
#      full_formula pretty_formula  candidate
# 20           B4N4             BN        0.0
# 66           B4N4             BN        0.0
# 73          W2Se4           WSe2        1.0
# 110          B2N2             BN        0.0
# 117         Mo2S4           MoS2        1.0
# 1239         B1N1             BN        0.0
# 1313        Mo2S4           MoS2        1.0
# 1361         B3N3             BN        0.0

# %% [markdown]
# ## Test set
# How many entries in our test set consists of known candidates?

# %%
Summary = pd.read_pickle(models_dir / InsertApproach / "summary" / "summary.pkl")
Summary.shape
# Out:
# (23594, 19)

# %%
Summary[Summary["pretty_formula"].isin(known_candidates)]
# Out:
#       material_id full_formula pretty_formula  RF    RF Prob  RF under  \
# 1654       mp-370        Cd1S1            CdS  1.0  1.000000       1.0
# 1656       mp-380       Zn2Se2           ZnSe  1.0  1.000000       1.0
# 1693       mp-672        Cd2S2            CdS  1.0  1.000000       1.0
# 1711       mp-830        Ga1N1            GaN  0.0  0.100000       0.0
# 1772      mp-1330        Al1N1            AlN  0.0  0.200000       0.0
# ...           ...          ...            ...  ...       ...       ...
# 24209  mp-1201781      Zn18S18            ZnS  1.0  1.000000       1.0
# 24271  mp-1202023      Zn18S18            ZnS  1.0  1.000000       1.0
# 24311  mp-1202182      Zn18S18            ZnS  1.0  1.000000       1.0
# 24514  mp-1202959      Zn18S18            ZnS  1.0  1.000000       1.0
# 24806  mp-1204046        Si106             Si  1.0  0.998718       1.0
#
#        RF underProb  RF over  RF overProb  RF both  RF bothProb  GB   \
# 
0
#
#         GB Prob  GB under  GB underProb  GB over  GB overProb  GB both  \
# 1731   0.000079       0.0      0.012727      0.0     0.019833      0.0
# 1788   0.999999       1.0      0.988455      1.0     0.978754      1.0
# 1809   0.000009       0.0      0.006542      0.0     0.015637      0.0
# 3353   0.000079       0.0      0.012727      0.0     0.019833      0.0
# 4408   0.000061       0.0      0.015145      0.0     0.030598      0.0
# 15113  0.000052       0.0      0.012727      0.0     0.019833      0.0
# 15899  0.000006       0.0      0.000942      0.0     0.001335      0.0
# 16239  0.000079       0.0      0.012727      0.0     0.019833      0.0
# 16617  0.000052       0.0      0.012710      0.0     0.019833      0.0
# 19847  0.000090       0.0      0.009762      0.0     0.026512      0.0
#
#        GB bothProb
# 1731      0.028894
# 1788      0.980498
# 1809      0.013445
# 3353      0.028877
# 4408      0.041385
# 15113     0.028894
# 15899     0.001517
# 16239     0.028844
# 16617     0.029346
# 19847     0.038024

# %% [markdown]
# ## How many entries does the models agree on?

# %%
Summary[(Summary["RF "] == 1) & 
        (Summary["RF under"] == 1) & 
        (Summary["RF over"] == 1) & 
        (Summary["RF both"] == 1) & 
        (Summary["GB "] == 1) & 
        (Summary["GB under"] == 1) & 
        (Summary["GB over"] == 1) & 
        (Summary["GB both"] == 1)]
# Out:
#       material_id   full_formula pretty_formula  RF   RF Prob  RF under  \
# 1618    mvc-12905          Fe4O8           FeO2  1.0      1.0       1.0
# 1628       mp-209        Er8Se12         Er2Se3  1.0      1.0       1.0
# 1629       mp-216        Sc16O24          Sc2O3  1.0      1.0       1.0
# 1630       mp-218        Sm16O24          Sm2O3  1.0      1.0       1.0
# 1631       mp-230         Sb8O16           SbO2  1.0      1.0       1.0
# ...           ...            ...            ...  ...      ...       ...
# 25206  mp-1304797  Sr12In4Ni4O24      Sr3InNiO6  1.0      1.0       1.0
# 25207  mp-1539137       Rb1Cr5S8        RbCr5S8  1.0      0.9       1.0
# 25208  mp-1541522        Bi2P2O8          BiPO4  1.0      0.9       1.0
# 25210  mp-1542038      Cs2Sn2Se6        CsSnSe3  1.0      0.9       1.0
# 25211  mp-1542939     Ba1Mo1P2O8     BaMo(PO4)2  1.0      0.9       1.0
#
#        RF underProb  RF over  RF overProb  RF both  RF bothProb  GB   \
# 1618       0.995251      1.0     0.998867      1.0     0.998697  1.0
# 1628       0.969987      1.0     0.970482      1.0     0.967714  1.0
# 1629       0.998243      1.0     0.999846      1.0     0.998368  1.0
# 1630       0.973713      1.0     0.990180      1.0     0.972980  1.0
# 1631       0.977259      1.0     0.987833      1.0     0.978299  1.0
# ...             ...      ...          ...      ...          ...  ...
# 25206      0.948637      1.0     0.975368      1.0     0.952758  1.0
# 25207      0.717509      1.0     0.796707      1.0     0.721820  1.0
# 25208      0.947087      1.0     0.906913      1.0     0.901247  1.0
# 25210      0.838496      1.0     0.871183      1.0     0.820124  1.0
# 25211      0.968457      1.0     0.917637      1.0     0.891042  1.0
#
#         GB Prob  GB under  GB underProb  GB over  GB overProb  GB both  \
# 1618   1.000000       1.0      0.999675      1.0     0.999618      1.0
# 1628   1.000000       1.0      0.999477      1.0     0.999417      1.0
# 1629   1.000000       1.0      0.999770      1.0     0.999772      1.0
# 1630   1.000000       1.0      0.999726      1.0     0.999703      1.0
# 1631   1.000000       1.0      0.996829      1.0     0.992768      1.0
# ...         ...       ...           ...      ...          ...      ...
# 25206  0.999812       1.0      0.999285      1.0     0.999451      1.0
# 25207  0.999609       1.0      0.971846      1.0     0.958785      1.0
# 25208  0.999998       1.0      0.997928      1.0     0.998351      1.0
# 25210  0.999940       1.0      0.994771      1.0     0.992499      1.0
# 25211  0.999999       1.0      0.998763      1.0     0.998129      1.0
#
#        GB bothProb
# 1618      0.999690
# 1628      0.999402
# 1629      0.999767
# 1630      0.999627
# 1631      0.992571
# ...            ...
# 25206     0.999385
# 25207     0.970737
# 25208     0.998496
# 25210     0.996654
# 25211     0.998487
#
# [11421 rows x 19 columns]
