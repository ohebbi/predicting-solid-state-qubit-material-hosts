# %% [markdown]
# # 06-post-analysis
#
# How can we verify if the trained models are correct in their predictions?
#
# One way is to verify against known candidates.

# %%
import sys
sys.path.insert(0, "../")

import pandas as pd
from pathlib import Path

data_dir = Path.cwd().parent.parent / "data"
models_dir = Path.cwd().parent.parent / "models" 

print("Current data directory {}".format(data_dir))
# Out:
# Current data directory /Users/ohebbi/Documents/UiO/Masterprosjekt/predicting-solid-state-qubit-candidates/data

# %%
known_candidates = ["C", "Si", "SiGe", "AlN", "GaN",
                   "AlP", "GaP", "AlAs", "ZnO", "ZnS", "ZnSe", "ZnTe", "CdS"]
QD_2D_candidates = ["BN", "MoS2", "WSe2", #2D
                    "LnAs" #QD
                   ]

# %%
InsertApproach = "01-naive-approach"

# %% [markdown]
# ## Training set
# How many entries in our training set consists of known candidates?

# %%
trainingSet   = pd.read_pickle(data_dir / InsertApproach / "processed" / "trainingSet.pkl")

# %%
trainingSet[["full_formula", "pretty_formula", "candidate"]][trainingSet["pretty_formula"].isin(known_candidates)]
# Out:
#      full_formula pretty_formula  candidate
# 3              C8              C        1.0
# 4              C4              C        1.0
# 5              C2              C        1.0
# 11            Si2             Si        1.0
# 12            Si4             Si        1.0
# 13             C2              C        1.0
# 29          Al2N2            AlN        0.0
# 40          Ga2N2            GaN        0.0
# 50         Zn1Se1           ZnSe        1.0
# 83          Zn1O1            ZnO        1.0
# 90         Zn1Te1           ZnTe        1.0
# 92          Zn1O1            ZnO        1.0
# 294         Al2P2            AlP        0.0
# 295        Al2As2           AlAs        0.0
# 296         Ga2P2            GaP        0.0
# 324         Zn1S1            ZnS        1.0
# 359         Zn1O1            ZnO        1.0
# 378          Si34             Si        1.0
# 951            C4              C        1.0
# 953            C8              C        1.0
# 958           C14              C        1.0
# 962        Zn2Se2           ZnSe        1.0
# 971            C8              C        1.0
# 1073           C8              C        1.0
# 1074          C12              C        1.0
# 1079          C16              C        1.0
# 1097          C60              C        1.0
# 1174          C60              C        1.0
# 1224          C60              C        1.0
# 1229         C140              C        1.0
# 1267         Si46             Si        1.0
# 1276          Si4             Si        1.0
# 1281           C4              C        1.0
# 1371           C8              C        1.0
# 1391           C8              C        1.0
# 1398         Si12             Si        1.0
# 1405          C12              C        1.0
# 1408          C12              C        1.0
# 1463          C16              C        1.0
# 1518         C240              C        1.0
# 1520         Si40             Si        1.0
# 1546         Si82             Si        1.0
# 1555         Si41             Si        1.0
# 1561        Si232             Si        1.0
# 1581         Si58             Si        1.0
# 1589          C48              C        1.0
# 1592         Si68             Si        1.0
# 1597         Si46             Si        1.0
# 1611          C20              C        1.0

# %%
trainingSet[["full_formula", "pretty_formula", "candidate"]][trainingSet["pretty_formula"].isin(QD_2D_candidates)]
# Out:
#      full_formula pretty_formula  candidate
# 20           B4N4             BN        0.0
# 66           B4N4             BN        0.0
# 73          W2Se4           WSe2        1.0
# 110          B2N2             BN        0.0
# 117         Mo2S4           MoS2        1.0
# 1239         B1N1             BN        0.0
# 1313        Mo2S4           MoS2        1.0
# 1361         B3N3             BN        0.0

# %% [markdown]
# ## Test set
# How many entries in our test set consists of known candidates?

# %%
Summary = pd.read_pickle(models_dir / InsertApproach / "summary" / "summary.pkl")
Summary.shape
# Out:
# (23594, 19)

# %%
Summary[Summary["pretty_formula"].isin(known_candidates)]
# Out:
#       material_id full_formula pretty_formula  RF    RF Prob  RF under  \
# 1654       mp-370        Cd1S1            CdS  1.0  0.816667       1.0
# 1656       mp-380       Zn2Se2           ZnSe  1.0  0.857692       1.0
# 1693       mp-672        Cd2S2            CdS  1.0  0.628829       0.0
# 1711       mp-830        Ga1N1            GaN  0.0  0.464744       0.0
# 1772      mp-1330        Al1N1            AlN  1.0  0.700000       0.0
# ...           ...          ...            ...  ...       ...       ...
# 24209  mp-1201781      Zn18S18            ZnS  1.0  0.668864       1.0
# 24271  mp-1202023      Zn18S18            ZnS  1.0  0.568864       1.0
# 24311  mp-1202182      Zn18S18            ZnS  1.0  0.568864       1.0
# 24514  mp-1202959      Zn18S18            ZnS  1.0  0.568864       1.0
# 24806  mp-1204046        Si106             Si  1.0  0.979121       1.0
#
#        RF underProb  RF over  RF overProb  RF both  RF bothProb  GB   \
# 
# 4408   0.960756       0.0  1.927761e-14      1.0  9.999730e-01      1.0
# 15113  0.008544       0.0  7.329897e-38      0.0  3.508864e-05      0.0
# 15899  0.003508       0.0  1.227066e-57      0.0  3.050177e-05      0.0
# 16239  0.000815       0.0  8.352170e-48      0.0  1.004996e-07      0.0
# 16617  0.228489       0.0  2.356573e-30      0.0  3.458651e-03      0.0
# 19847  0.965983       0.0  1.247770e-06      1.0  9.839168e-01      1.0
#
#         GB bothProb
# 1731   2.471242e-01
# 1788   9.997078e-01
# 1809   2.912531e-04
# 3353   9.094836e-01
# 4408   9.999995e-01
# 15113  1.034031e-04
# 15899  8.651284e-07
# 16239  6.301157e-08
# 16617  1.634817e-02
# 19847  9.985477e-01

# %% [markdown]
# ## How many entries does the models agree on?

# %%
Summary[(Summary["RF "] == 1) & 
        (Summary["RF under"] == 1) & 
        (Summary["RF over"] == 1) & 
        (Summary["RF both"] == 1) & 
        (Summary["GB "] == 1) & 
        (Summary["GB under"] == 1) & 
        (Summary["GB over"] == 1) & 
        (Summary["GB both"] == 1)]
# Out:
#       material_id   full_formula pretty_formula  RF    RF Prob  RF under  \
# 1618    mvc-12905          Fe4O8           FeO2  1.0  0.866667       1.0
# 1626       mp-189         Si4Ru4           SiRu  1.0  0.996386       1.0
# 1629       mp-216        Sc16O24          Sc2O3  1.0  1.000000       1.0
# 1630       mp-218        Sm16O24          Sm2O3  1.0  0.841667       1.0
# 1631       mp-230         Sb8O16           SbO2  1.0  0.706977       1.0
# ...           ...            ...            ...  ...       ...       ...
# 25206  mp-1304797  Sr12In4Ni4O24      Sr3InNiO6  1.0  0.983633       1.0
# 25207  mp-1539137       Rb1Cr5S8        RbCr5S8  1.0  0.800000       1.0
# 25208  mp-1541522        Bi2P2O8          BiPO4  1.0  0.821667       1.0
# 25210  mp-1542038      Cs2Sn2Se6        CsSnSe3  1.0  0.889184       1.0
# 25211  mp-1542939     Ba1Mo1P2O8     BaMo(PO4)2  1.0  0.900000       1.0
#
#        RF underProb  RF over  RF overProb  RF both  RF bothProb  GB   \
# 1618       0.733909      1.0     0.872981      1.0     0.877019  1.0
# 1626       0.536557      1.0     0.699101      1.0     0.725807  1.0
# 1629       0.624061      1.0     0.785416      1.0     0.756754  1.0
# 1630       0.593007      1.0     0.825855      1.0     0.797835  1.0
# 1631       0.572470      1.0     0.670210      1.0     0.662328  1.0
# ...             ...      ...          ...      ...          ...  ...
# 25206      0.685645      1.0     0.738639      1.0     0.727278  1.0
# 25207      0.580397      1.0     0.676285      1.0     0.682652  1.0
# 25208      0.547440      1.0     0.639705      1.0     0.587916  1.0
# 25210      0.575325      1.0     0.647768      1.0     0.650244  1.0
# 25211      0.707550      1.0     0.819099      1.0     0.828191  1.0
#
#         GB Prob  GB under  GB underProb  GB over  GB overProb  GB both  \
# 1618   1.000000       1.0      1.000000      1.0     1.000000      1.0
# 1626   0.641771       1.0      0.910771      1.0     0.715613      1.0
# 1629   0.994718       1.0      1.000000      1.0     0.999999      1.0
# 1630   0.999888       1.0      1.000000      1.0     1.000000      1.0
# 1631   0.880115       1.0      1.000000      1.0     0.913318      1.0
# ...         ...       ...           ...      ...          ...      ...
# 25206  0.999709       1.0      1.000000      1.0     1.000000      1.0
# 25207  0.997158       1.0      1.000000      1.0     0.999996      1.0
# 25208  0.968716       1.0      1.000000      1.0     0.999947      1.0
# 25210  0.997989       1.0      1.000000      1.0     0.999039      1.0
# 25211  0.999981       1.0      1.000000      1.0     1.000000      1.0
#
#        GB bothProb
# 1618      1.000000
# 1626      0.979556
# 1629      0.999983
# 1630      1.000000
# 1631      0.917592
# ...            ...
# 25206     1.000000
# 25207     0.999999
# 25208     0.999907
# 25210     0.999940
# 25211     1.000000
#
# [12228 rows x 19 columns]
