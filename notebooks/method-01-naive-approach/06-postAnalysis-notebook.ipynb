# %% [markdown]
# # 06-post-analysis
#
# How can we verify if the trained models are correct in their predictions?
#
# One way is to verify against known candidates.

# %%
import sys
sys.path.insert(0, "../")

import pandas as pd
from pathlib import Path

data_dir = Path.cwd().parent.parent / "data"
models_dir = Path.cwd().parent.parent / "models" 

print("Current data directory {}".format(data_dir))
# Out:
# Current data directory /home/oliver/Dokumenter/masterprosjekt/predicting-solid-state-qubit-candidates/data

# %%
known_candidates = ["C", "Si", "SiGe", "AlN", "GaN",
                   "AlP", "GaP", "AlAs", "ZnO", "ZnS", "ZnSe", "ZnTe", "CdS"]
QD_2D_candidates = ["BN", "MoS2", "WSe2", #2D
                    "LnAs" #QD
                   ]

# %%
InsertApproach = "01-naive-approach"

# %% [markdown]
# ## Training set
# How many entries in our training set consists of known candidates?

# %%
trainingSet   = pd.read_pickle(data_dir / InsertApproach / "processed" / "trainingSet.pkl")

# %%
trainingSet[["full_formula", "pretty_formula", "candidate"]][trainingSet["pretty_formula"].isin(known_candidates)]
# Out:
#      full_formula pretty_formula  candidate
# 3              C8              C        1.0
# 4              C4              C        1.0
# 5              C2              C        1.0
# 11            Si2             Si        1.0
# 12            Si4             Si        1.0
# 13             C2              C        1.0
# 29          Al2N2            AlN        0.0
# 40          Ga2N2            GaN        0.0
# 50         Zn1Se1           ZnSe        1.0
# 83          Zn1O1            ZnO        1.0
# 90         Zn1Te1           ZnTe        1.0
# 92          Zn1O1            ZnO        1.0
# 294         Al2P2            AlP        0.0
# 295        Al2As2           AlAs        0.0
# 296         Ga2P2            GaP        0.0
# 324         Zn1S1            ZnS        1.0
# 359         Zn1O1            ZnO        1.0
# 378          Si34             Si        1.0
# 951            C4              C        1.0
# 953            C8              C        1.0
# 958           C14              C        1.0
# 962        Zn2Se2           ZnSe        1.0
# 971            C8              C        1.0
# 1073           C8              C        1.0
# 1074          C12              C        1.0
# 1079          C16              C        1.0
# 1097          C60              C        1.0
# 1174          C60              C        1.0
# 1224          C60              C        1.0
# 1229         C140              C        1.0
# 1267         Si46             Si        1.0
# 1276          Si4             Si        1.0
# 1281           C4              C        1.0
# 1371           C8              C        1.0
# 1391           C8              C        1.0
# 1398         Si12             Si        1.0
# 1405          C12              C        1.0
# 1408          C12              C        1.0
# 1463          C16              C        1.0
# 1518         C240              C        1.0
# 1520         Si40             Si        1.0
# 1546         Si82             Si        1.0
# 1555         Si41             Si        1.0
# 1561        Si232             Si        1.0
# 1581         Si58             Si        1.0
# 1589          C48              C        1.0
# 1592         Si68             Si        1.0
# 1597         Si46             Si        1.0
# 1611          C20              C        1.0

# %%
trainingSet[["full_formula", "pretty_formula", "candidate"]][trainingSet["pretty_formula"].isin(QD_2D_candidates)]
# Out:
#      full_formula pretty_formula  candidate
# 20           B4N4             BN        0.0
# 66           B4N4             BN        0.0
# 73          W2Se4           WSe2        1.0
# 110          B2N2             BN        0.0
# 117         Mo2S4           MoS2        1.0
# 1239         B1N1             BN        0.0
# 1313        Mo2S4           MoS2        1.0
# 1361         B3N3             BN        0.0

# %% [markdown]
# ## Test set
# How many entries in our test set consists of known candidates?

# %%
Summary = pd.read_pickle(models_dir / InsertApproach / "summary" / "summary.pkl")
Summary.shape
# Out:
# (23594, 19)

# %%
Summary[Summary["pretty_formula"].isin(known_candidates)]
# Out:
#       material_id full_formula pretty_formula  R
pretty_formula"].isin(QD_2D_candidates)]
# Out:
#       material_id full_formula pretty_formula  RF    RF Prob  RF under  \
# 1731       mp-984         B2N2             BN  1.0  0.527298       0.0
# 1788      mp-1434        Mo1S2           MoS2  1.0  0.870719       1.0
# 1809      mp-1639         B1N1             BN  1.0  0.605937       0.0
# 3353      mp-7991         B2N2             BN  1.0  0.723474       0.0
# 4408     mp-13151         B4N4             BN  1.0  0.595714       0.0
# 15113   mp-569655         B4N4             BN  1.0  0.760903       0.0
# 15899   mp-604884         B2N2             BN  1.0  0.565244       0.0
# 16239   mp-629015         B2N2             BN  0.0  0.370928       0.0
# 16617   mp-644751         B4N4             BN  1.0  0.562981       0.0
# 19847  mp-1060281         B1N1             BN  1.0  0.846444       1.0
#
#        RF underProb  RF over  RF overProb  RF both  RF bothProb  GB   \
# 1731       0.387551      0.0     0.491773      1.0     0.520565  1.0
# 1788       0.646127      1.0     0.684500      1.0     0.625942  1.0
# 1809       0.412013      0.0     0.418487      0.0     0.441551  0.0
# 3353       0.474322      0.0     0.491857      1.0     0.578300  1.0
# 4408       0.480146      1.0     0.509766      1.0     0.568343  0.0
# 15113      0.344795      0.0     0.454344      1.0     0.521444  0.0
# 15899      0.227864      0.0     0.315603      0.0     0.430974  0.0
# 16239      0.265808      0.0     0.329907      0.0     0.404328  0.0
# 16617      0.448817      0.0     0.468104      1.0     0.520350  0.0
# 19847      0.585729      1.0     0.642138      1.0     0.673971  1.0
#
#         GB Prob  GB under  GB underProb  GB over   GB overProb  GB both  \
# 1731   0.907570       0.0  1.119564e-02      0.0  7.676707e-02      0.0
# 1788   0.996876       1.0  9.999942e-01      1.0  9.997471e-01      1.0
# 1809   0.034377       0.0  1.130678e-03      0.0  3.014943e-03      0.0
# 3353   0.961187       0.0  7.560087e-03      0.0  5.678192e-02      0.0
# 4408   0.420366       1.0  9.890065e-01      1.0  5.751805e-01      0.0
# 15113  0.038413       0.0  4.753977e-06      0.0  3.995767e-03      0.0
# 15899  0.034320       0.0  6.905997e-10      0.0  6.014010e-07      0.0
# 16239  0.012364       0.0  1.774939e-08      0.0  4.966775e-06      0.0
# 16617  0.197802       0.0  2.494219e-02      0.0  3.278488e-04      0.0
# 19847  0.993061       1.0  9.833394e-01      1.0  9.946139e-01      1.0
#
#         GB bothProb
# 1731   7.809551e-02
# 1788   9.999058e-01
# 1809   7.434849e-03
# 3353   3.402943e-01
# 4408   7.113419e-02
# 15113  1.607435e-03
# 15899  1.731214e-06
# 16239  8.431667e-07
# 16617  3.652462e-04
# 19847  9.864960e-01

# %% [markdown]
# ## How many entries does the models agree on?

# %%
Summary[(Summary["RF "] == 1) & 
        (Summary["RF under"] == 1) & 
        (Summary["RF over"] == 1) & 
        (Summary["RF both"] == 1) & 
        (Summary["GB "] == 1) & 
        (Summary["GB under"] == 1) & 
        (Summary["GB over"] == 1) & 
        (Summary["GB both"] == 1)]
# Out:
#       material_id   full_formula pretty_formula  RF    RF Prob  RF under  \
# 1618    mvc-12905          Fe4O8           FeO2  1.0  0.980340       1.0
# 1626       mp-189         Si4Ru4           SiRu  1.0  0.810611       1.0
# 1628       mp-209        Er8Se12         Er2Se3  1.0  0.863999       1.0
# 1629       mp-216        Sc16O24          Sc2O3  1.0  0.746362       1.0
# 1630       mp-218        Sm16O24          Sm2O3  1.0  0.957789       1.0
# ...           ...            ...            ...  ...       ...       ...
# 25206  mp-1304797  Sr12In4Ni4O24      Sr3InNiO6  1.0  0.825467       1.0
# 25207  mp-1539137       Rb1Cr5S8        RbCr5S8  1.0  0.990546       1.0
# 25208  mp-1541522        Bi2P2O8          BiPO4  1.0  0.718976       1.0
# 25210  mp-1542038      Cs2Sn2Se6        CsSnSe3  1.0  0.674862       1.0
# 25211  mp-1542939     Ba1Mo1P2O8     BaMo(PO4)2  1.0  0.978955       1.0
#
#        RF underProb  RF over  RF overProb  RF both  RF bothProb  GB   \
# 1618       0.846875      1.0     0.856948      1.0     0.830487  1.0
# 1626       0.517078      1.0     0.580267      1.0     0.540658  1.0
# 1628       0.583030      1.0     0.707533      1.0     0.640698  1.0
# 1629       0.677161      1.0     0.723651      1.0     0.713616  1.0
# 1630       0.683602      1.0     0.745372      1.0     0.788392  1.0
# ...             ...      ...          ...      ...          ...  ...
# 25206      0.754300      1.0     0.699520      1.0     0.701092  1.0
# 25207      0.689718      1.0     0.713214      1.0     0.696632  1.0
# 25208      0.521795      1.0     0.651983      1.0     0.622710  1.0
# 25210      0.593504      1.0     0.579103      1.0     0.602124  1.0
# 25211      0.822223      1.0     0.839702      1.0     0.769820  1.0
#
#         GB Prob  GB under  GB underProb  GB over  GB overProb  GB both  \
# 1618   0.999893       1.0      1.000000      1.0     1.000000      1.0
# 1626   0.927319       1.0      1.000000      1.0     0.994939      1.0
# 1628   0.799406       1.0      0.999032      1.0     0.972986      1.0
# 1629   0.971750       1.0      0.988999      1.0     0.999989      1.0
# 1630   0.996500       1.0      0.999999      1.0     0.999976      1.0
# ...         ...       ...           ...      ...          ...      ...
# 25206  0.998949       1.0      1.000000      1.0     0.999427      1.0
# 25207  0.989415       1.0      0.905016      1.0     0.999721      1.0
# 25208  0.939947       1.0      0.981909      1.0     0.998598      1.0
# 25210  0.975251       1.0      0.997358      1.0     0.997574      1.0
# 25211  0.999321       1.0      0.999999      1.0     1.000000      1.0
#
#        GB bothProb
# 1618      1.000000
# 1626      0.989257
# 1628      0.998543
# 1629      0.999995
# 1630      0.999954
# ...            ...
# 25206     0.999224
# 25207     0.997292
# 25208     0.988101
# 25210     0.991640
# 25211     0.999999
#
# [12429 rows x 19 columns]
