# %% [markdown]
# # Build features
#
# In this notebook we will go through how we can build features with the python library matminer [citation]. Some always, we start off with some imports.

# %%
# Optional: Load the "autoreload" extension so that code can change
# %load_ext autoreload

#OPTIONAL: Always reload modules so that as you change code in src, it gets loaded
# %autoreload 2

# %%
import sys 
sys.path.insert(0, "../")

import os

import pandas as pd
import numpy as np
from tqdm import tqdm

from src.data.get_data_MP import data_MP
from src.features.build_features import featurize_by_material_id
from src.features.featurizeAll import FeaturizeAll
# Ignore warnings from nan-values in  
np.warnings.filterwarnings('ignore')

# Find and store all API-keys that are stored as environment variables .env in root folder
from dotenv import find_dotenv, load_dotenv
key_status = load_dotenv(find_dotenv())

# Private keys. If not present, add your own secret keys here
if (key_status):
    MAPI_KEY = os.getenv("MAPI_KEY")
    CAPI_KEY = os.getenv("CAPI_KEY")
else: 
    MAPI_KEY = None
    CAPI_KEY = None

from pathlib import Path
data_dir = Path.cwd().parent / "data"
print("Current data directory {}".format(data_dir))
# Out:
# Current data directory /home/oliver/Dokumenter/masterprosjekt/predicting-solid-state-qubit-candidates-v2/data

# %%
MP = data_MP(API_KEY=MAPI_KEY)
entries = MP.get_dataframe()
print("Number of entries after query: {}".format(len(entries)))
# Out:
# Data path /home/oliver/Dokumenter/masterprosjekt/predicting-solid-state-qubit-candidates-v2/data/raw/MP/MP.pkl detected. Reading now...
# Done
# Number of entries after query: 25212

# %%
#featurizerObject = FeaturizeAll()
#df = featurize_by_material_id(entries["material_id"].iloc[:2], featurizerObject, "b7RtVfJTsUg6TK8E")

# %%
def sortByMPID(df):
    mpid_num = []
    for i in df["material_id"]:
        mpid_num.append(int(i[3:]))
    df["mpid_num"] = mpid_num
    df = df.sort_values(by="mpid_num").reset_index(drop=True)
    df = df.drop(columns=["mpid_num"])
    #df = df.set_index("material_id")
    return df

# %% [markdown]
# # Oxidation

# %%
MP_oxidation_featurized = pd.read_csv(data_dir / "interim" / "Featurized" / "MP_oxidationFeaturized.csv", sep=",")
print(MP_oxidation_featurized.shape)
#MP_oxidation_featurized = findIdenticalIDs(MP_oxidation_featurized)
#MP_oxidation_featurized
# Out:
# (25270, 113)

# %%
def findIdenticalIDs(someEntries):
    dropIds = np.zeros(len(someEntries))
    for i, mpid in tqdm(enumerate(someEntries["material_id"])):
        for j in entries["material_id"]:
            if mpid==j:
                dropIds[i] += 1
    return someEntries.drop(np.where(dropIds==0)[0]).reset_index(drop=True)

# %%
MP_oxidation_featurized = findIdenticalIDs(MP_oxidation_featurized)
MP_oxidation_featurized.shape
# Out:
# 25270it [00:44, 565.59it/s]
# (25201, 113)

# %%
dropIds1 = np.zeros(len(entries))
for i, mpid in tqdm(enumerate(entries["material_id"])):
    for j in MP_oxidation_featurized["material_id"]:
        if mpid==j:
            dropIds1[i] += 1
# Out:
# 25212it [01:00, 420.05it/s]

# %%
entries["material_id"][np.where(dropIds1 == 0)[0]].values
# Out:
# array(['mp-20946', 'mp-31624', 'mp-565970', 'mp-568700', 'mp-644925',
#        'mp-1101391', 'mp-1101820', 'mp-1172939', 'mp-1179149',
#        'mp-1180710', 'mp-1293833'], dtype=object)

# %%
drop_columns = ["composition", "composition_oxid"]
MP_oxidation_featurized = MP_oxidation_featurized.drop(drop_columns, axis=1)

# %% [markdown]
# # Electronic

# %%
MP_electronic_featurized = pd.read_csv(data_dir / "interim" / "Featurized" / "MP_electronicFeaturized.csv", sep=",", index_col=0)
print(MP_electronic_featurized.shape)
MP_electronic_featurized = findIdenticalIDs(MP_electronic_featurized)
MP_electronic_featurized.shape
# Out:
# 55it [00:00, 544.84it/s]
# (25271, 19)
# 25271it [00:44, 565.10it/s]
# (25201, 19)

# %%
drop_columns = ["full_formula"]
MP_electronic_featurized = MP_electronic_featurized.drop(drop_columns, axis=1)

MP_electronic_featurized

dropIds2 = np.zeros(len(entries))
for i, mpid in tqdm(enumerate(entries["material_id"])):
    for j in MP_electronic_featurized["material_id"]:
        if mpid==j:
            dropIds2[i] += 1
# Out:
# 25212it [01:00, 415.51it/s]

# %%
#MP_electronic_featurized = MP_electronic_featurized.join(MP_oxidation_featurized.set_index('material_id'), on='material_id')
#MP_electronic_featurized = sortByMPID(MP_electronic_featurized)
#bandGaps["featurized_Eg"] = MP_electronic_featurized.pop("band_gap")
#MP_electronic_featurized
entries["material_id"][np.where(dropIds2 == 0)[0]].values
# Out:
# array(['mp-20946', 'mp-31624', 'mp-565970', 'mp-568700', 'mp-644925',
#        'mp-1101391', 'mp-1101820', 'mp-1172939', 'mp-1179149',
#        'mp-1180710', 'mp-1293833'], dtype=object)

# %% [markdown]
# # The rest

# %%
MP_rest_of_featurizers = pd.read_pickle(data_dir / "interim" / "Featurized" / "MP_featurizedAll.pkl")
MP_rest_of_featurizers.shape
# Out:
# (25212, 4700)

# %%
MP_rest_of_featurizers = findIdenticalIDs(MP_rest_of_featurizers)
# Out:
# 25212it [00:44, 568.55it/s]

# %%
MP_rest_of_featurizers.shape
# Out:
# (25212, 4700)

# %%
#MP_electronic_featurized = MP_electronic_featurized.join(MP_rest_of_featurizers.set_index('material_id'), on='material_id')

# %%
dropIds3 = np.zeros(len(entries))
for i, mpid in tqdm(enumerate(entries["material_id"])):
    for j in MP_rest_of_featurizers["material_id"]:
        if mpid==j:
            dropIds3[i] += 1
# Out:
# 25212it [01:06, 380.06it/s]

# %%
entries["material_id"][np.where(dropIds3 == 0)[0]].values
# Out:
# array([], dtype=object)

# %%
slettAlleDisse = list(entries["material_id"][np.where(dropIds1 == 0)[0]].values)\
               + list(entries["material_id"][np.where(dropIds2 == 0)[0]].values)\
               + list(entries["material_id"][np.where(dropIds3 == 0)[0]].values)
slettAlleDisse = list(set(slettAlleDisse))
print(len(slettAlleDisse))
slettAlleDisse
# Out:
# 11
# ['mp-1101820',
#  'mp-1180710',
#  'mp-20946',
#  'mp-1293833',
#  'mp-1179149',
#  'mp-1172939',
#  'mp-644925',
#  'mp-565970',
#  'mp-31624',
#  'mp-568700',
#  'mp-1101391']

# %% [markdown]
# ## slette

# %%
for i in slettAlleDisse:
    try:
        MP_rest_of_featurizers   = MP_rest_of_featurizers  [MP_rest_of_featurizers  ["material_id"] != i]
    except: 
        continue
for i in slettAlleDisse:
    try:
        MP_oxidation_featurized  = MP_oxidation_featurized [MP_oxidation_featurized ["material_id"] != i]
    except: 
        continue
for i in slettAlleDisse:
    try:
        MP_electronic_featurized = MP_electronic_featurized[MP_electronic_featurized["material_id"] != i]
    except: 
        continue

# %%
MP_rest_of_featurizers.shape
# Out:
# (25201, 4700)

# %%
MP_electronic_featurized.shape
# Out:
# (25201, 18)

# %%
MP_oxidation_featurized.shape
# Out:
# (25201, 111)

# %% [markdown]
# # Featurize the rest

# %%
leggtiligjen = slettAlleDisse
featurizerObject = FeaturizeAll()
df = featurize_by_material_id(leggtiligjen, featurizerObject, MAPI_KEY)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 9962.72it/s]
# Downloading dos and bandstructure objects..
#                   full_formula  \
# material_id
# mp-1101391   Sr4Re8H32C6N12O42
# mp-1101820            Mg1Ti3H8
# mp-1172939       Na2Mg4H6S4O16
# mp-1179149            Sr2Mo2O8
# mp-1180710          Na24B52O90
# mp-1293833             Y2Fe4O8
# mp-20946            Ba1Y1Fe2O5
# mp-31624          Sr8Ta4Cr4O24
# mp-565970              Ba2W2O8
# mp-568700             Na5Li1N2
# mp-644925        Cs10Bi2Mo8O32
#
#                                                  bandstructure  \
# material_id
# mp-1101391                                                None
# mp-1101820                                                None
# mp-1172939                                                None
# mp-1179149                                                None
# mp-1180710                                                None
# mp-1293833                                                None
# mp-20946                                                  None
# mp-31624     <pymatgen.electronic_structure.bandstructure.B...
# mp-565970                                                 None
# mp-568700                                                 None
# mp-644925                                                 None
#
#                                                            dos  \
# material_id
# mp-1101391                                                None
# mp-1101820                                                None
# mp-1172939                                                None
# mp-1179149                                                None
# mp-1180710                                                None
# mp-1293833                                                None
# mp-20946                                                  None
# mp-31624     Complete DOS for Full Formula (Sr2 Ta1 Cr1 O6)...
# mp-565970                                                 None
# mp-568700                                                 None
# mp-644925                                                 None
#
#                                                      structure
# material_id
# mp-1101391   [[ 2.8456614  11.91095975 17.34663639] Sr, [ 4...
# mp-1101820   [[0. 0. 0.] Mg, [2.2302375 2.2302375 0.       ...
# mp-1172939   [[-0.37935798  5.70749987 -1.07713573] Na, [2....
# mp-1179149   [[1.35749647 3.20177386 3.31645489] Sr, [ 2.80...
# mp-1180710   [[ 3.3654476   3.1754474  14.73664177] Na, [ 6...
# mp-1293833   [[ 1.83848743 -3.04470205  8.67369867] Y, [ 1....
# mp-20946     [[0. 0. 0.] Ba, [0.       0.       3.805566] Y...
# mp-31624     [[-3.26332172  1.15375663  5.6522557 ] Sr, [ 8...
# mp-565970    [[4.75796041 7.073212   3.045861  ] Ba, [-4.75...
# mp-568700    [[0.779044 3.022054 0.      ] Na, [-0.88493829...
# mp-644925    [[5.41943483 5.5101318  6.94524191] Cs, [8.250...
# Applying composition featurizers...
# Applying featurizers (AtomicOrbitals(), AtomicPackingEfficiency(), BandCenter(), ElementFraction(), ElementProperty(data_source=<matminer.utils.data.MagpieData object at 0x7f8168b938b0>,
#                 features=['Number', 'MendeleevNumber', 'AtomicWeight',
#                           'MeltingT', 'Column', 'Row', 'CovalentRadius',
#                           'Electronegativity', 'NsValence', 'NpValence',
#                           'NdValence', 'NfValence', 'NValence', 'NsUnfilled',
#                           'NpUnfilled', 'NdUnfilled', 'NfUnfilled', 'NUnfilled',
#                           'GSvolume_pa', 'GSbandgap', 'GSmagmom',
#                           'SpaceGroupNumber'],
#                 stats=['minimum', 'maximum', 'range', 'mean', 'avg_dev',
#                        'mode']), IonProperty(), Miedema(ss_types=['min'], struct_types=['inter', 'amor', 'ss']), Stoichiometry(), TMetalFraction(), ValenceOrbital(), YangSolidSolution()) to column 'composition'.
# MultipleFeaturizer:   0%|          | 0/11 [00:00<?, ?it/s]
# Applying oxidation state featurizers...
# CompositionToOxidComposition:   0%|          | 0/11 [00:00<?, ?it/s]
# Applying featurizers (ElectronegativityDiff(stats=['minimum', 'maximum', 'range', 'mean', 'std_dev']), OxidationStates(stats=['minimum', 'maximum', 'range', 'std_dev'])) to column 'composition_oxid'.
# MultipleFeaturizer:   0%|          | 0/11 [00:00<?, ?it/s]
# Applying structure featurizers...
# Applying featurizers (DensityFeatures(), GlobalSymmetryFeatures(), RadialDistributionFunction(), CoulombMatrix(), PartialRadialDistributionFunction(exclude_elems=[], include_elems=[]), SineCoulombMatrix(), EwaldEnergy(), BondFractions(), StructuralHeterogeneity(), MaximumPackingEfficiency(), ChemicalOrdering(), XRDPowderPattern(pattern_length=128)) to column 'structure'.
# MultipleFeaturizer:   0%|          | 0/11 [00:00<?, ?it/s]
# Applying site featurizers...
# SiteStatsFingerprint:   0%|          | 0/11 [00:00<?, ?it/s]
# SiteStatsFingerprint:   0%|          | 0/11 [00:00<?, ?it/s]
# SiteStatsFingerprint:   0%|          | 0/11 [00:00<?, ?it/s]
# SiteStatsFingerprint:   0%|          | 0/11 [00:00<?, ?it/s]
# SiteStatsFingerprint:   0%|          | 0/11 [00:00<?, ?it/s]
# SiteStatsFingerprint:   0%|          | 0/11 [00:00<?, ?it/s]
# SiteStatsFingerprint:   0%|          | 0/11 [00:00<?, ?it/s]
# SiteStatsFingerprint:   0%|          | 0/11 [00:00<?, ?it/s]
# SiteStatsFingerprint:   0%|          | 0/11 [00:00<?, ?it/s]
# SiteStatsFingerprint:   0%|          | 0/11 [00:00<?, ?it/s]
# SiteStatsFingerprint:   0%|          | 0/11 [00:00<?, ?it/s]
# SiteStatsFingerprint:   0%|          | 0/11 [00:00<?, ?it/s]
# Applying dos featurizers...
# DOSFeaturizer()
# <class 'matminer.featurizers.dos.DOSFeaturizer'>
# Applying featurizers DOSFeaturizer() to column 'dos'.
# DOSFeaturizer:   0%|          | 0/11 [00:00<?, ?it/s]
# DOSFeaturizer|cbm_location_1
# material_id
# mp-1101391              0
# mp-1101820              0
# mp-1172939              0
# mp-1179149              0
# mp-1180710              0
# mp-1293833              0
# mp-20946                0
# mp-31624      0.0;0.0;0.0
# mp-565970               0
# mp-568700               0
# mp-644925               0
# Name: DOSFeaturizer|cbm_location_1, dtype: object
# DOSFeaturizer|vbm_location_1
# material_id
# mp-1101391              0
# mp-1101820              0
# mp-1172939              0
# mp-1179149              0
# mp-1180710              0
# mp-1293833              0
# mp-20946                0
# mp-31624      0.0;0.0;0.0
# mp-565970               0
# mp-568700               0
# mp-644925               0
# Name: DOSFeaturizer|vbm_location_1, dtype: object
# Applying bandstructure featurizers...
# Applying featurizers BandFeaturizer() to column 'bandstructure'.
# BandFeaturizer:   0%|          | 0/11 [00:00<?, ?it/s]

# %%
df
# Out:
#              DOSFeaturizer|cbm_hybridization  DOSFeaturizer|cbm_character_1  \
# material_id
# mp-1101391                          0.000000                           -1.0
# mp-1101820                          0.000000                           -1.0
# mp-1172939                          0.000000                           -1.0
# mp-1179149                          0.000000                           -1.0
# mp-1180710                          0.000000                           -1.0
# mp-1293833                          0.000000                           -1.0
# mp-20946                            0.000000                           -1.0
# mp-31624                            1.282979                            3.0
# mp-565970                           0.000000                           -1.0
# mp-568700                           0.000000                           -1.0
# mp-644925                           0.000000                           -1.0
#
#              DOSFeaturizer|cbm_score_1  DOSFeaturizer|vbm_hybridization  \
# material_id
# mp-1101391                    0.000000                         0.000000
# mp-1101820                    0.000000                         0.000000
# mp-1172939                    0.000000                         0.000000
# mp-1179149                    0.000000                         0.000000
# mp-1180710                    0.000000                         0.000000
# mp-1293833                    0.000000                         0.000000
# mp-20946                      0.000000                         0.000000
# mp-31624                      0.459716                         1.898573
# mp-565970                     0.000000                         0.000000
# mp-568700                     0.000000                         0.000000
# mp-644925                     0.000000                         0.000000
#
#              DOSFeaturizer|vbm_character_1  DOSFeaturizer|vbm_score_1  \
# material_id
# mp-1101391                            -1.0                   0.000000
# mp-1101820                            -1.0                   0.000000
# mp-1172939                            -1.0                   0.000000
# mp-1179149                            -1.0                   0.000000
# mp-1180710                            -1.0                   0.000000
# mp-1293833                            -1.0                   0.000000
# mp-20946                              -1.0                   0.000000
# mp-31624                               3.0                   0.346259
# mp-565970                             -1.0                   0.000000
# mp-568700                             -1.0                   0.000000
# mp-644925                             -1.0                   0.000000
#
#              DOSFeaturizer|vbm_specie_1_0  DOSFeaturizer|vbm_specie_1_Cr  \
# material_id
# mp-1101391                              1                              0
# mp-1101820                              1                              0
# mp-1172939                              1                              0
# mp-1179149                              1                              0
# mp-1180710                              1                              0
# mp-1293833                              1                              0
# mp-20946                                1                              0
# mp-31624                                0                              1
# mp-565970                               1                              0
# mp-568700                               1                              0
# mp-644925                               1                              0
#
#              DOSFeaturizer|cbm_specie_1_0  DOSFeaturizer|cbm_specie_1_Cr  ...  \
# material_id                                                               ...
# mp-1101391                              1                              0  ...
# mp-1101820                              1                              0  ...
# mp-1172939                              1                              0  ...
# mp-1179149                              1                              0  ...
# mp-1180710                              1                              0  ...
# mp-1293833                              1                              0  ...
# mp-20946                                1                              0  ...
# mp-31624                                0                              1  ...
# mp-565970                               1                              0  ...
# mp-568700                               1                              0  ...
# mp-644925                               1                              0  ...
#
#              VoronoiFingerprint|mean Voro_area_maximum  \
# material_id
# mp-1101391                                    7.023839
# mp-1101820                                    2.477590
# mp-1172939                                    6.240850
# mp-1179149                                    5.755912
# mp-1180710                                   -1.000000
# mp-1293833                                    6.752630
# mp-20946                                      5.019930
# mp-31624                                      3.777399
# mp-565970                                     6.121136
# mp-568700                                     3.201073
# mp-644925                                     7.320761
#
#              VoronoiFingerprint|std_dev Voro_area_maximum  \
# material_id
# mp-1101391                                       0.976089
# mp-1101820                                       0.045546
# mp-1172939                                       0.863647
# mp-1179149                                       0.483486
# mp-1180710                                      -1.000000
# mp-1293833                                       0.836450
# mp-20946                                         0.567587
# mp-31624                                         0.477091
# mp-565970                                        0.406202
# mp-568700                                        0.025254
# mp-644925                                        0.659151
#
#              VoronoiFingerprint|mean Voro_dist_mean  \
# material_id
# mp-1101391                                 3.035521
# mp-1101820                                 2.051067
# mp-1172939                                 2.889165
# mp-1179149                                 3.075222
# mp-1180710                                -1.000000
# mp-1293833                                 3.038188
# mp-20946                                   2.896172
# mp-31624                                   2.759744
# mp-565970                                  3.218010
# mp-568700                                  2.840116
# mp-644925                                  3.422939
#
#              VoronoiFingerprint|std_dev Voro_dist_mean  \
# material_id
# mp-1101391                                    0.301694
# mp-1101820                                    0.085124
# mp-1172939                                    0.248961
# mp-1179149                                    0.274846
# mp-1180710                                   -1.000000
# mp-1293833                                    0.233231
# mp-20946                                      0.185482
# mp-31624                                      0.334006
# mp-565970                                     0.302527
# mp-568700                                     0.045773
# mp-644925                                     0.154667
#
#              VoronoiFingerprint|mean Voro_dist_std_dev  \
# material_id
# mp-1101391                                    0.787671
# mp-1101820                                    0.099675
# mp-1172939                                    0.709780
# mp-1179149                                    0.617884
# mp-1180710                                   -1.000000
# mp-1293833                                    0.644195
# mp-20946                                      0.463701
# mp-31624                                      0.347495
# mp-565970                                     0.664342
# mp-568700                                     0.262754
# mp-644925                                     0.693968
#
#              VoronoiFingerprint|std_dev Voro_dist_std_dev  \
# material_id
# mp-1101391                                       0.158788
# mp-1101820                                       0.070481
# mp-1172939                                       0.147942
# mp-1179149                                       0.025133
# mp-1180710                                      -1.000000
# mp-1293833                                       0.115239
# mp-20946                                         0.122813
# mp-31624                                         0.181992
# mp-565970                                        0.033245
# mp-568700                                        0.053513
# mp-644925                                        0.233997
#
#              VoronoiFingerprint|mean Voro_dist_minimum  \
# material_id
# mp-1101391                                    1.385053
# mp-1101820                                    1.924555
# mp-1172939                                    1.495602
# mp-1179149                                    1.941150
# mp-1180710                                   -1.000000
# mp-1293833                                    2.032979
# mp-20946                                      2.159141
# mp-31624                                      2.159428
# mp-565970                                     1.984310
# mp-568700                                     2.517868
# mp-644925                                     2.038679
#
#              VoronoiFingerprint|std_dev Voro_dist_minimum  \
# material_id
# mp-1101391                                       0.412354
# mp-1101820                                       0.011716
# mp-1172939                                       0.426623
# mp-1179149                                       0.304674
# mp-1180710                                      -1.000000
# mp-1293833                                       0.101709
# mp-20946                                         0.267067
# mp-31624                                         0.333376
# mp-565970                                        0.362062
# mp-568700                                        0.111403
# mp-644925                                        0.463190
#
#              VoronoiFingerprint|mean Voro_dist_maximum  \
# material_id
# mp-1101391                                    4.156663
# mp-1101820                                    2.155308
# mp-1172939                                    3.888789
# mp-1179149                                    4.078832
# mp-1180710                                   -1.000000
# mp-1293833                                    4.042751
# mp-20946                                      3.473805
# mp-31624                                      3.046604
# mp-565970                                     4.265212
# mp-568700                                     3.377436
# mp-644925                                     4.524545
#
#              VoronoiFingerprint|std_dev Voro_dist_maximum
# material_id
# mp-1101391                                       0.333327
# mp-1101820                                       0.158526
# mp-1172939                                       0.314001
# mp-1179149                                       0.420009
# mp-1180710                                      -1.000000
# mp-1293833                                       0.263548
# mp-20946                                         0.360242
# mp-31624                                         0.579343
# mp-565970                                        0.433473
# mp-568700                                        0.092917
# mp-644925                                        0.260474
#
# [11 rows x 1412 columns]

# %%
df = df.reset_index()
df
# Out:
#    material_id  DOSFeaturizer|cbm_hybridization  \
# 0   mp-1101391                         0.000000
# 1   mp-1101820                         0.000000
# 2   mp-1172939                         0.000000
# 3   mp-1179149                         0.000000
# 4   mp-1180710                         0.000000
# 5   mp-1293833                         0.000000
# 6     mp-20946                         0.000000
# 7     mp-31624                         1.282979
# 8    mp-565970                         0.000000
# 9    mp-568700                         0.000000
# 10   mp-644925                         0.000000
#
#     DOSFeaturizer|cbm_character_1  DOSFeaturizer|cbm_score_1  \
# 0                            -1.0                   0.000000
# 1                            -1.0                   0.000000
# 2                            -1.0                   0.000000
# 3                            -1.0                   0.000000
# 4                            -1.0                   0.000000
# 5                            -1.0                   0.000000
# 6                            -1.0                   0.000000
# 7                             3.0                   0.459716
# 8                            -1.0                   0.000000
# 9                            -1.0                   0.000000
# 10                           -1.0                   0.000000
#
#     DOSFeaturizer|vbm_hybridization  DOSFeaturizer|vbm_character_1  \
# 0                          0.000000                           -1.0
# 1                          0.000000                           -1.0
# 2                          0.000000                           -1.0
# 3                          0.000000                           -1.0
# 4                          0.000000                           -1.0
# 5                          0.000000                           -1.0
# 6                          0.000000                           -1.0
# 7                          1.898573                            3.0
# 8                          0.000000                           -1.0
# 9                          0.000000                           -1.0
# 10                         0.000000                           -1.0
#
#     DOSFeaturizer|vbm_score_1  DOSFeaturizer|vbm_specie_1_0  \
# 0                    0.000000                             1
# 1                    0.000000                             1
# 2                    0.000000                             1
# 3                    0.000000                             1
# 4                    0.000000                             1
# 5                    0.000000                             1
# 6                    0.000000                             1
# 7                    0.346259                             0
# 8                    0.000000                             1
# 9                    0.000000                             1
# 10                   0.000000                             1
#
#     DOSFeaturizer|vbm_specie_1_Cr  DOSFeaturizer|cbm_specie_1_0  ...  \
# 0                               0                             1  ...
# 1                               0                             1  ...
# 2                               0                             1  ...
# 3                               0                             1  ...
# 4                               0                             1  ...
# 5                               0                             1  ...
# 6                               0                             1  ...
# 7                               1                             0  ...
# 8                               0                             1  ...
# 9                               0                             1  ...
# 10                              0                             1  ...
#
#     VoronoiFingerprint|mean Voro_area_maximum  \
# 0                                    7.023839
# 1                                    2.477590
# 2                                    6.240850
# 3                                    5.755912
# 4                                   -1.000000
# 5                                    6.752630
# 6                                    5.019930
# 7                                    3.777399
# 8                                    6.121136
# 9                                    3.201073
# 10                                   7.320761
#
#     VoronoiFingerprint|std_dev Voro_area_maximum  \
# 0                                       0.976089
# 1                                       0.045546
# 2                                       0.863647
# 3                                       0.483486
# 4                                      -1.000000
# 5                                       0.836450
# 6                                       0.567587
# 7                                       0.477091
# 8                                       0.406202
# 9                                       0.025254
# 10                                      0.659151
#
#     VoronoiFingerprint|mean Voro_dist_mean  \
# 0                                 3.035521
# 1                                 2.051067
# 2                                 2.889165
# 3                                 3.075222
# 4                                -1.000000
# 5                                 3.038188
# 6                                 2.896172
# 7                                 2.759744
# 8                                 3.218010
# 9                                 2.840116
# 10                                3.422939
#
#     VoronoiFingerprint|std_dev Voro_dist_mean  \
# 0                                    0.301694
# 1                                    0.085124
# 2                                    0.248961
# 3                                    0.274846
# 4                                   -1.000000
# 5                                    0.233231
# 6                                    0.185482
# 7                                    0.334006
# 8                                    0.302527
# 9                                    0.045773
# 10                                   0.154667
#
#     VoronoiFingerprint|mean Voro_dist_std_dev  \
# 0                                    0.787671
# 1                                    0.099675
# 2                                    0.709780
# 3                                    0.617884
# 4                                   -1.000000
# 5                                    0.644195
# 6                                    0.463701
# 7                                    0.347495
# 8                                    0.664342
# 9                                    0.262754
# 10                                   0.693968
#
#     VoronoiFingerprint|std_dev Voro_dist_std_dev  \
# 0                                       0.158788
# 1                                       0.070481
# 2                                       0.147942
# 3                                       0.025133
# 4                                      -1.000000
# 5                                       0.115239
# 6                                       0.122813
# 7                                       0.181992
# 8                                       0.033245
# 9                                       0.053513
# 10                                      0.233997
#
#     VoronoiFingerprint|mean Voro_dist_minimum  \
# 0                                    1.385053
# 1                                    1.924555
# 2                                    1.495602
# 3                                    1.941150
# 4                                   -1.000000
# 5                                    2.032979
# 6                                    2.159141
# 7                                    2.159428
# 8                                    1.984310
# 9                                    2.517868
# 10                                   2.038679
#
#     VoronoiFingerprint|std_dev Voro_dist_minimum  \
# 0                                       0.412354
# 1                                       0.011716
# 2                                       0.426623
# 3                                       0.304674
# 4                                      -1.000000
# 5                                       0.101709
# 6                                       0.267067
# 7                                       0.333376
# 8                                       0.362062
# 9                                       0.111403
# 10                                      0.463190
#
#     VoronoiFingerprint|mean Voro_dist_maximum  \
# 0                                    4.156663
# 1                                    2.155308
# 2                                    3.888789
# 3                                    4.078832
# 4                                   -1.000000
# 5                                    4.042751
# 6                                    3.473805
# 7                                    3.046604
# 8                                    4.265212
# 9                                    3.377436
# 10                                   4.524545
#
#     VoronoiFingerprint|std_dev Voro_dist_maximum
# 0                                       0.333327
# 1                                       0.158526
# 2                                       0.314001
# 3                                       0.420009
# 4                                      -1.000000
# 5                                       0.263548
# 6                                       0.360242
# 7                                       0.579343
# 8                                       0.433473
# 9                                       0.092917
# 10                                      0.260474
#
# [11 rows x 1413 columns]

# %% [markdown]
# # Add together all contributions

# %%
MP_electronic_featurized = MP_electronic_featurized.join(MP_oxidation_featurized.set_index('material_id'), on='material_id')

# %%
MP_ALL_featurized = MP_rest_of_featurizers.join(MP_oxidation_featurized.set_index('material_id'), on='material_id')

# %%
MP_ALL_featurized
# Out:
#       material_id  AtomicOrbitals|HOMO_character  AtomicOrbitals|HOMO_element  \
# 0       mvc-12905                            3.0                           26
# 1            mp-7                            2.0                           16
# 2           mp-14                            2.0                           34
# 3           mp-19                            2.0                           52
# 4           mp-24                            2.0                            6
# ...           ...                            ...                          ...
# 25207  mp-1539137                            3.0                           24
# 25208  mp-1541522                            2.0                            8
# 25209  mp-1541714                            2.0                           17
# 25210  mp-1542038                            2.0                           34
# 25211  mp-1542939                            2.0                            8
#
#        AtomicOrbitals|HOMO_energy  AtomicOrbitals|LUMO_character  \
# 0                       -0.295049                            3.0
# 1                       -0.261676                            2.0
# 2                       -0.245806                            2.0
# 3                       -0.226594                            2.0
# 4                       -0.199186                            2.0
# ...                           ...                            ...
# 25207                   -0.118123                            3.0
# 25208                   -0.338381                            2.0
# 25209                   -0.320380                            2.0
# 25210                   -0.245806                            2.0
# 25211                   -0.338381                            2.0
#
#        AtomicOrbitals|LUMO_element  AtomicOrbitals|LUMO_energy  \
# 0                               26                   -0.295049
# 1                               16                   -0.261676
# 2                               34                   -0.245806
# 3                               52                   -0.226594
# 4                                6                   -0.199186
# ...                            ...                         ...
# 25207                           24                   -0.118123
# 25208                            8                   -0.338381
# 25209                           33                   -0.197497
# 25210                           34                   -0.245806
# 25211                            8                   -0.338381
#
#        AtomicOrbitals|gap_AO  \
# 0                   0.000000
# 1                   0.000000
# 2                   0.000000
# 3                   0.000000
# 4                   0.000000
# ...                      ...
# 25207               0.000000
# 25208               0.000000
# 25209               0.122883
# 25210               0.000000
# 25211               0.000000
#
#        AtomicPackingEfficiency|mean simul. packing efficiency  \
# 0                                              -0.037170
# 1                                               0.023994
# 2                                               0.023994
# 3                                               0.023994
# 4                                               0.023994
# ...                                                  ...
# 25207                                           0.043418
# 25208                                           0.043618
# 25209                                           0.000000
# 25210                                          -0.017041
# 25211                                           0.032738
#
#        AtomicPackingEfficiency|mean abs simul. packing efficiency  ...  Es  \
# 0                                               0.037170           ...   0
# 1                                               0.023994           ...   0
# 2                                               0.023994           ...   0
# 3                                               0.023994           ...   0
# 4                                               0.023994           ...   0
# ...                                                  ...           ...  ..
# 25207                                           0.043418           ...   0
# 25208                                           0.045390           ...   0
# 25209                                           0.000000           ...   0
# 25210                                           0.039003           ...   0
# 25211                                           0.032855           ...   0
#
#        Fm  Md  No  Lr  minimum EN difference  maximum EN difference  \
# 0       0   0   0   0                    NaN                    NaN
# 1       0   0   0   0                    NaN                    NaN
# 2       0   0   0   0                    NaN                    NaN
# 3       0   0   0   0                    NaN                    NaN
# 4       0   0   0   0                    NaN                    NaN
# ...    ..  ..  ..  ..                    ...                    ...
# 25207   0   0   0   0                   0.92                   1.76
# 25208   0   0   0   0                   1.25                   1.42
# 25209   0   0   0   0                   0.98                   2.37
# 25210   0   0   0   0                   0.59                   1.76
# 25211   0   0   0   0                   1.25                   2.55
#
#        range EN difference  mean EN difference  std_dev EN difference
# 0                      NaN                 NaN                    NaN
# 1                      NaN                 NaN                    NaN
# 2                      NaN                 NaN                    NaN
# 3                      NaN                 NaN                    NaN
# 4                      NaN                 NaN                    NaN
# ...                    ...                 ...                    ...
# 25207                 0.84              1.0600               0.593970
# 25208                 0.17              1.3350               0.120208
# 25209                 1.39              1.8140               0.982878
# 25210                 1.17              1.1750               0.827315
# 25211                 1.30              1.5825               0.706732
#
# [25201 rows x 4810 columns]

# %%
ALL = pd.concat([MP_ALL_featurized,df])

# %%
ALL = sortByMPID(ALL)

# %%
ALL
# Out:
#       material_id  AtomicOrbitals|HOMO_character  AtomicOrbitals|HOMO_element  \
# 0       mvc-12905                            3.0                           26
# 1            mp-7                            2.0                           16
# 2           mp-14                            2.0                           34
# 3           mp-19                            2.0                           52
# 4           mp-24                            2.0                            6
# ...           ...                            ...                          ...
# 25207  mp-1539137                            3.0                           24
# 25208  mp-1541522                            2.0                            8
# 25209  mp-1541714                            2.0                           17
# 25210  mp-1542038                            2.0                           34
# 25211  mp-1542939                            2.0                            8
#
#        AtomicOrbitals|HOMO_energy  AtomicOrbitals|LUMO_character  \
# 0                       -0.295049                            3.0
# 1                       -0.261676                            2.0
# 2                       -0.245806                            2.0
# 3                       -0.226594                            2.0
# 4                       -0.199186                            2.0
# ...                           ...                            ...
# 25207                   -0.118123                            3.0
# 25208                   -0.338381                            2.0
# 25209                   -0.320380                            2.0
# 25210                   -0.245806                            2.0
# 25211                   -0.338381                            2.0
#
#        AtomicOrbitals|LUMO_element  AtomicOrbitals|LUMO_energy  \
# 0                               26                   -0.295049
# 1                               16                   -0.261676
# 2                               34                   -0.245806
# 3                               52                   -0.226594
# 4                                6                   -0.199186
# ...                            ...                         ...
# 25207                           24                   -0.118123
# 25208                            8                   -0.338381
# 25209                           33                   -0.197497
# 25210                           34                   -0.245806
# 25211                            8                   -0.338381
#
#        AtomicOrbitals|gap_AO  \
# 0                   0.000000
# 1                   0.000000
# 2                   0.000000
# 3                   0.000000
# 4                   0.000000
# ...                      ...
# 25207               0.000000
# 25208               0.000000
# 25209               0.122883
# 25210               0.000000
# 25211               0.000000
#
#        AtomicPackingEfficiency|mean simul. packing efficiency  \
# 0                                              -0.037170
# 1                                               0.023994
# 2                                               0.023994
# 3                                               0.023994
# 4                                               0.023994
# ...                                                  ...
# 25207                                           0.043418
# 25208                                           0.043618
# 25209                                           0.000000
# 25210                                          -0.017041
# 25211                                           0.032738
#
#        AtomicPackingEfficiency|mean abs simul. packing efficiency  ...  \
# 0                                               0.037170           ...
# 1                                               0.023994           ...
# 2                                               0.023994           ...
# 3                                               0.023994           ...
# 4                                               0.023994           ...
# ...                                                  ...           ...
# 25207                                           0.043418           ...
# 25208                                           0.045390           ...
# 25209                                           0.000000           ...
# 25210                                           0.039003           ...
# 25211                                           0.032855           ...
#
#        BandFeaturizer|n_ex1_degen  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 25207                         NaN
# 25208                         NaN
# 25209                         NaN
# 25210                         NaN
# 25211                         NaN
#
#        ElectronegativityDiff|minimum EN difference  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 25207                                          NaN
# 25208                                          NaN
# 25209                                          NaN
# 25210                                          NaN
# 25211                                          NaN
#
#        ElectronegativityDiff|maximum EN difference  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 25207                                          NaN
# 25208                                          NaN
# 25209                                          NaN
# 25210                                          NaN
# 25211                                          NaN
#
#        ElectronegativityDiff|range EN difference  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 25207                                        NaN
# 25208                                        NaN
# 25209                                        NaN
# 25210                                        NaN
# 25211                                        NaN
#
#        ElectronegativityDiff|mean EN difference  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 25207                                       NaN
# 25208                                       NaN
# 25209                                       NaN
# 25210                                       NaN
# 25211                                       NaN
#
#        ElectronegativityDiff|std_dev EN difference  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 25207                                          NaN
# 25208                                          NaN
# 25209                                          NaN
# 25210                                          NaN
# 25211                                          NaN
#
#        OxidationStates|minimum oxidation state  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 25207                                      NaN
# 25208                                      NaN
# 25209                                      NaN
# 25210                                      NaN
# 25211                                      NaN
#
#        OxidationStates|maximum oxidation state  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 25207                                      NaN
# 25208                                      NaN
# 25209                                      NaN
# 25210                                      NaN
# 25211                                      NaN
#
#        OxidationStates|range oxidation state  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 25207                                    NaN
# 25208                                    NaN
# 25209                                    NaN
# 25210                                    NaN
# 25211                                    NaN
#
#        OxidationStates|std_dev oxidation state
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 25207                                      NaN
# 25208                                      NaN
# 25209                                      NaN
# 25210                                      NaN
# 25211                                      NaN
#
# [25212 rows x 4842 columns]

# %% [markdown]
# ## Sette på ny som er bra for alle. Nå er det godt system.

# %% [markdown]
# # Add band gap from other databases

# %%
bandgaps = pd.read_pickle(data_dir / "interim" / "bandgaps.pkl")
bandgaps
# Out:
#       material_id   MP_Eg  OQMD_Eg  AFLOW_Eg  AFLOW-fitted_Eg  AFLOWML_Eg  \
# 0       mvc-12905  1.2690      NaN       NaN              NaN       1.047
# 1            mp-7  2.4881    2.085    2.5251          4.31683       2.490
# 2           mp-14  1.0119      NaN    0.9784          2.23188       0.997
# 3           mp-19  0.5752      NaN    0.1534          1.11978         NaN
# 4           mp-24  2.7785      NaN    2.4528          4.21937       3.355
# ...           ...     ...      ...       ...              ...         ...
# 25209  mp-1539137  0.3523    0.508       NaN              NaN       0.584
# 25210  mp-1541522  4.0039      NaN       NaN              NaN       3.445
# 25211  mp-1541714  2.6408      NaN       NaN              NaN       2.857
# 25212  mp-1542038  1.2725      NaN       NaN              NaN       1.094
# 25213  mp-1542939  1.7196      NaN       NaN              NaN       2.024
#
#        JARVIS-TBMBJ_Eg  JARVIS-OPT_Eg  Exp_Eg  spillage
# 0                  NaN            NaN     NaN       NaN
# 1               3.0448         1.9604     NaN       NaN
# 2               2.2888         0.8982     NaN       NaN
# 3               0.6148         0.1655     NaN     1.318
# 4               3.3186         2.7427     NaN       NaN
# ...                ...            ...     ...       ...
# 25209              NaN            NaN     NaN       NaN
# 25210              NaN            NaN     NaN       NaN
# 25211              NaN            NaN     NaN       NaN
# 25212              NaN            NaN     NaN       NaN
# 25213              NaN            NaN     NaN       NaN
#
# [25214 rows x 10 columns]

# %%
ALL = ALL.join(bandgaps.set_index('material_id'), on='material_id')
ALL
# Out:
#       material_id  AtomicOrbitals|HOMO_character  AtomicOrbitals|HOMO_element  \
# 0       mvc-12905                            3.0                           26
# 1            mp-7                            2.0                           16
# 2           mp-14                            2.0                           34
# 3           mp-19                            2.0                           52
# 4           mp-24                            2.0                            6
# ...           ...                            ...                          ...
# 25207  mp-1539137                            3.0                           24
# 25208  mp-1541522                            2.0                            8
# 25209  mp-1541714                            2.0                           17
# 25210  mp-1542038                            2.0                           34
# 25211  mp-1542939                            2.0                            8
#
#        AtomicOrbitals|HOMO_energy  AtomicOrbitals|LUMO_character  \
# 0                       -0.295049                            3.0
# 1                       -0.261676                            2.0
# 2                       -0.245806                            2.0
# 3                       -0.226594                            2.0
# 4                       -0.199186                            2.0
# ...                           ...                            ...
# 25207                   -0.118123                            3.0
# 25208                   -0.338381                            2.0
# 25209                   -0.320380                            2.0
# 25210                   -0.245806                            2.0
# 25211                   -0.338381                            2.0
#
#        AtomicOrbitals|LUMO_element  AtomicOrbitals|LUMO_energy  \
# 0                               26                   -0.295049
# 1                               16                   -0.261676
# 2                               34                   -0.245806
# 3                               52                   -0.226594
# 4                                6                   -0.199186
# ...                            ...                         ...
# 25207                           24                   -0.118123
# 25208                            8                   -0.338381
# 25209                           33                   -0.197497
# 25210                           34                   -0.245806
# 25211                            8                   -0.338381
#
#        AtomicOrbitals|gap_AO  \
# 0                   0.000000
# 1                   0.000000
# 2                   0.000000
# 3                   0.000000
# 4                   0.000000
# ...                      ...
# 25207               0.000000
# 25208               0.000000
# 25209               0.122883
# 25210               0.000000
# 25211               0.000000
#
#        AtomicPackingEfficiency|mean simul. packing efficiency  \
# 0                                              -0.037170
# 1                                               0.023994
# 2                                               0.023994
# 3                                               0.023994
# 4                                               0.023994
# ...                                                  ...
# 25207                                           0.043418
# 25208                                           0.043618
# 25209                                           0.000000
# 25210                                          -0.017041
# 25211                                           0.032738
#
#        AtomicPackingEfficiency|mean abs simul. packing efficiency  ...  \
# 0                                               0.037170           ...
# 1                                               0.023994           ...
# 2                                               0.023994           ...
# 3                                               0.023994           ...
# 4                                               0.023994           ...
# ...                                                  ...           ...
# 25207                                           0.043418           ...
# 25208                                           0.045390           ...
# 25209                                           0.000000           ...
# 25210                                           0.039003           ...
# 25211                                           0.032855           ...
#
#        OxidationStates|std_dev oxidation state   MP_Eg  OQMD_Eg  AFLOW_Eg  \
# 0                                          NaN  1.2690      NaN       NaN
# 1                                          NaN  2.4881    2.085    2.5251
# 2                                          NaN  1.0119      NaN    0.9784
# 3                                          NaN  0.5752      NaN    0.1534
# 4                                          NaN  2.7785      NaN    2.4528
# ...                                        ...     ...      ...       ...
# 25207                                      NaN  0.3523    0.508       NaN
# 25208                                      NaN  4.0039      NaN       NaN
# 25209                                      NaN  2.6408      NaN       NaN
# 25210                                      NaN  1.2725      NaN       NaN
# 25211                                      NaN  1.7196      NaN       NaN
#
#        AFLOW-fitted_Eg  AFLOWML_Eg  JARVIS-TBMBJ_Eg  JARVIS-OPT_Eg  Exp_Eg  \
# 0                  NaN       1.047              NaN            NaN     NaN
# 1              4.31683       2.490           3.0448         1.9604     NaN
# 2              2.23188       0.997           2.2888         0.8982     NaN
# 3              1.11978         NaN           0.6148         0.1655     NaN
# 4              4.21937       3.355           3.3186         2.7427     NaN
# ...                ...         ...              ...            ...     ...
# 25207              NaN       0.584              NaN            NaN     NaN
# 25208              NaN       3.445              NaN            NaN     NaN
# 25209              NaN       2.857              NaN            NaN     NaN
# 25210              NaN       1.094              NaN            NaN     NaN
# 25211              NaN       2.024              NaN            NaN     NaN
#
#        spillage
# 0           NaN
# 1           NaN
# 2           NaN
# 3         1.318
# 4           NaN
# ...         ...
# 25207       NaN
# 25208       NaN
# 25209       NaN
# 25210       NaN
# 25211       NaN
#
# [25212 rows x 4851 columns]

# %%
ALL.to_pickle(data_dir / "interim" / "featurized" / "featurizedData.pkl")
