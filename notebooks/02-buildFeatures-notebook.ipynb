# %% [markdown]
# # Build features
#
# In this notebook we will go through how we can build features with the python library matminer [citation]. Some always, we start off with some imports.

# %%
# Optional: Load the "autoreload" extension so that code can change
# %load_ext autoreload

#OPTIONAL: Always reload modules so that as you change code in src, it gets loaded
# %autoreload 2

# %%
import sys 
sys.path.insert(0, "../")

import os

import pandas as pd
import numpy as np
from tqdm import tqdm

from src.data.get_data_MP import data_MP
from src.features.build_features import featurize_by_material_id
from src.features.preset import PRESET_HEBNES_2021
# Ignore warnings from nan-values in  
np.warnings.filterwarnings('ignore')

# Find and store all API-keys that are stored as environment variables .env in root folder
from dotenv import find_dotenv, load_dotenv
key_status = load_dotenv(find_dotenv())

# Private keys. If not present, add your own secret keys here
if (key_status):
    MAPI_KEY = os.getenv("MAPI_KEY")
else: 
    MAPI_KEY = None #ADD HERE

from pathlib import Path
data_dir = Path.cwd().parent / "data"
print("Current data directory {}".format(data_dir))
# Out:
# If you use the ChemEnv tool for your research, please consider citing the following reference(s) :
# ==================================================================================================
# David Waroquiers, Xavier Gonze, Gian-Marco Rignanese, Cathrin Welker-Nieuwoudt, Frank Rosowski,
# Michael Goebel, Stephan Schenk, Peter Degelmann, Rute Andre, Robert Glaum, and Geoffroy Hautier,
# "Statistical analysis of coordination environments in oxides",
# Chem. Mater., 2017, 29 (19), pp 8346-8360,
# DOI: 10.1021/acs.chemmater.7b02766
#
# Current data directory /Users/ohebbi/Documents/UiO/Masterprosjekt/predicting-solid-state-qubit-candidates/data

# %%
MP = data_MP(API_KEY=MAPI_KEY)
entries = MP.get_dataframe()
print("Number of entries after query: {}".format(len(entries)))
# Out:
# Data path /home/oliver/Dokumenter/masterprosjekt/predicting-solid-state-qubit-candidates/data/raw/MP/MP.pkl detected. Reading now...
# Done
# Number of entries after query: 25212

# %%
#featurizerObject = PRESET_HEBNES_2021()
#df = featurize_by_material_id(entries["material_id"].iloc[:2], featurizerObject, "b7RtVfJTsUg6TK8E")

# %%
def sortByMPID(df):
    mpid_num = []
    for i in df["material_id"]:
        mpid_num.append(int(i[3:]))
    df["mpid_num"] = mpid_num
    df = df.sort_values(by="mpid_num").reset_index(drop=True)
    df = df.drop(columns=["mpid_num"])
    #df = df.set_index("material_id")
    return df

# %% [markdown]
# # Oxidation

# %%
MP_oxidation_featurized = pd.read_csv(data_dir / "interim" / "featurized" / "MP_oxidationFeaturized.csv", sep=",")
print(MP_oxidation_featurized.shape)
#MP_oxidation_featurized = findIdenticalIDs(MP_oxidation_featurized)
#MP_oxidation_featurized
# Out:
# (25270, 113)

# %%
def findIdenticalIDs(someEntries):
    dropIds = np.zeros(len(someEntries))
    for i, mpid in tqdm(enumerate(someEntries["material_id"])):
        for j in entries["material_id"]:
            if mpid==j:
                dropIds[i] += 1
    return someEntries.drop(np.where(dropIds==0)[0]).reset_index(drop=True)

# %%
MP_oxidation_featurized = findIdenticalIDs(MP_oxidation_featurized)
MP_oxidation_featurized.shape
# Out:
# 25270it [00:43, 578.82it/s]
# (25201, 113)

# %%
dropIds1 = np.zeros(len(entries))
for i, mpid in tqdm(enumerate(entries["material_id"])):
    for j in MP_oxidation_featurized["material_id"]:
        if mpid==j:
            dropIds1[i] += 1
# Out:
# 25212it [00:57, 435.75it/s]

# %%
entries["material_id"][np.where(dropIds1 == 0)[0]].values
# Out:
# array(['mp-20946', 'mp-31624', 'mp-565970', 'mp-568700', 'mp-644925',
#        'mp-1101391', 'mp-1101820', 'mp-1172939', 'mp-1179149',
#        'mp-1180710', 'mp-1293833'], dtype=object)

# %%
drop_columns = ["composition", "composition_oxid"]
MP_oxidation_featurized = MP_oxidation_featurized.drop(drop_columns, axis=1)

# %% [markdown]
# # Electronic

# %%
MP_electronic_featurized = pd.read_csv(data_dir / "interim" / "featurized" / "MP_electronicFeaturized.csv", sep=",", index_col=0)
print(MP_electronic_featurized.shape)
MP_electronic_featurized = findIdenticalIDs(MP_electronic_featurized)
MP_electronic_featurized.shape
# Out:
# 56it [00:00, 558.36it/s]
# (25271, 19)
# 25271it [00:43, 580.57it/s]
# (25201, 19)

# %%
drop_columns = ["full_formula"]
MP_electronic_featurized = MP_electronic_featurized.drop(drop_columns, axis=1)

MP_electronic_featurized

dropIds2 = np.zeros(len(entries))
for i, mpid in tqdm(enumerate(entries["material_id"])):
    for j in MP_electronic_featurized["material_id"]:
        if mpid==j:
            dropIds2[i] += 1
# Out:
# 25212it [00:57, 435.22it/s]

# %%
entries["material_id"][np.where(dropIds2 == 0)[0]].values
# Out:
# array(['mp-20946', 'mp-31624', 'mp-565970', 'mp-568700', 'mp-644925',
#        'mp-1101391', 'mp-1101820', 'mp-1172939', 'mp-1179149',
#        'mp-1180710', 'mp-1293833'], dtype=object)

# %% [markdown]
# # The rest

# %%
MP_rest_of_featurizers = pd.read_pickle(data_dir / "interim" / "featurized" / "MP_featurizedAll.pkl")
MP_rest_of_featurizers.shape
# Out:
# (25212, 4700)

# %%
MP_rest_of_featurizers = findIdenticalIDs(MP_rest_of_featurizers)
# Out:
# 25212it [00:43, 579.34it/s]

# %%
MP_rest_of_featurizers.shape
# Out:
# (25212, 4700)

# %%
#MP_electronic_featurized = MP_electronic_featurized.join(MP_rest_of_featurizers.set_index('material_id'), on='material_id')

# %%
dropIds3 = np.zeros(len(entries))
for i, mpid in tqdm(enumerate(entries["material_id"])):
    for j in MP_rest_of_featurizers["material_id"]:
        if mpid==j:
            dropIds3[i] += 1
# Out:
# 25212it [01:00, 413.53it/s]

# %%
entries["material_id"][np.where(dropIds3 == 0)[0]].values
# Out:
# array([], dtype=object)

# %%
slettAlleDisse = list(entries["material_id"][np.where(dropIds1 == 0)[0]].values)\
               + list(entries["material_id"][np.where(dropIds2 == 0)[0]].values)\
               + list(entries["material_id"][np.where(dropIds3 == 0)[0]].values)
slettAlleDisse = list(set(slettAlleDisse))
print(len(slettAlleDisse))
slettAlleDisse
# Out:
# 11
# ['mp-1179149',
#  'mp-1101391',
#  'mp-565970',
#  'mp-1172939',
#  'mp-1180710',
#  'mp-20946',
#  'mp-31624',
#  'mp-1101820',
#  'mp-568700',
#  'mp-1293833',
#  'mp-644925']

# %% [markdown]
# ## slette

# %%
for i in slettAlleDisse:
    try:
        MP_rest_of_featurizers   = MP_rest_of_featurizers  [MP_rest_of_featurizers  ["material_id"] != i]
    except: 
        continue
for i in slettAlleDisse:
    try:
        MP_oxidation_featurized  = MP_oxidation_featurized [MP_oxidation_featurized ["material_id"] != i]
    except: 
        continue
for i in slettAlleDisse:
    try:
        MP_electronic_featurized = MP_electronic_featurized[MP_electronic_featurized["material_id"] != i]
    except: 
        continue

# %%
MP_rest_of_featurizers.shape
# Out:
# (25201, 4700)

# %%
MP_electronic_featurized.shape
# Out:
# (25201, 18)

# %%
MP_oxidation_featurized.shape
# Out:
# (25201, 111)

# %%
# Out:
# ['mp-1179149',
#  'mp-1101391',
#  'mp-565970',
#  'mp-1172939',
#  'mp-1180710',
#  'mp-20946',
#  'mp-31624',
#  'mp-1101820',
#  'mp-568700',
#  'mp-1293833',
#  'mp-644925']

# %% [markdown]
# # Featurize the rest

# %%
leggtiligjen = slettAlleDisse
featurizerObject = PRESET_HEBNES_2021()
df = featurize_by_material_id(leggtiligjen, featurizerObject, MAPI_KEY)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 14563.56it/s]
# Downloading dos and bandstructure objects..
#                   full_formula  \
# material_id
# mp-1101391   Sr4Re8H32C6N12O42
# mp-1101820            Mg1Ti3H8
# mp-1172939       Na2Mg4H6S4O16
# mp-1179149            Sr2Mo2O8
# mp-1180710          Na24B52O90
# mp-1293833             Y2Fe4O8
# mp-20946            Ba1Y1Fe2O5
# mp-31624          Sr8Ta4Cr4O24
# mp-565970              Ba2W2O8
# mp-568700             Na5Li1N2
# mp-644925        Cs10Bi2Mo8O32
#
#                                                  bandstructure  \
# material_id
# mp-1101391                                                None
# mp-1101820                                                None
# mp-1172939                                                None
# mp-1179149                                                None
# mp-1180710                                                None
# mp-1293833                                                None
# mp-20946                                                  None
# mp-31624     <pymatgen.electronic_structure.bandstructure.B...
# mp-565970                                                 None
# mp-568700                                                 None
# mp-644925                                                 None
#
#                                                            dos  \
# material_id
# mp-1101391                                                None
# mp-1101820                                                None
# mp-1172939                                                None
# mp-1179149                                                None
# mp-1180710                                                None
# mp-1293833                                                None
# mp-20946                                                  None
# mp-31624     Complete DOS for Full Formula (Sr2 Ta1 Cr1 O6)...
# mp-565970                                                 None
# mp-568700                                                 None
# mp-644925                                                 None
#
#                                                      structure
# material_id
# mp-1101391   [[ 2.8456614  11.91095975 17.34663639] Sr, [ 4...
# mp-1101820   [[0. 0. 0.] Mg, [2.2302375 2.2302375 0.       ...
# mp-1172939   [[-0.37935798  5.70749987 -1.07713573] Na, [2....
# mp-1179149   [[1.35749647 3.20177386 3.31645489] Sr, [ 2.80...
# mp-1180710   [[ 3.3654476   3.1754474  14.73664177] Na, [ 6...
# mp-1293833   [[ 1.83848743 -3.04470205  8.67369867] Y, [ 1....
# mp-20946     [[0. 0. 0.] Ba, [0.       0.       3.805566] Y...
# mp-31624     [[-3.26332172  1.15375663  5.6522557 ] Sr, [ 8...
# mp-565970    [[4.75796041 7.073212   3.045861  ] Ba, [-4.75...
# mp-568700    [[0.779044 3.022054 0.      ] Na, [-0.88493829...
# mp-644925    [[5.41943483 5.5101318  6.94524191] Cs, [8.250...
# Applying dos featurizers...
# Applying featurizers DOSFeaturizer() to column 'dos'.
# DOSFeaturizer:   0%|          | 0/11 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-ecd5c4547af9> in <module>
#       1 leggtiligjen = slettAlleDisse
#       2 featurizerObject = PRESET_HEBNES_2021()
# ----> 3 df = featurize_by_material_id(leggtiligjen, featurizerObject, MAPI_KEY)
#
# ~/Dokumenter/masterprosjekt/predicting-solid-state-qubit-candidates/src/features/build_features.py in featurize_by_material_id(material_ids, featurizerObject, MAPI_KEY)
#      35     if (leftover):
#      36         criteria = {"task_id":{"$in":list(material_ids[i:i+leftover])}}
# ---> 37         df_portion = apply_featurizers(criteria, properties, mpdr, featurizerObject)
#      38         df = pd.concat([df,df_portion])
#      39     return df
#
# ~/Dokumenter/masterprosjekt/predicting-solid-state-qubit-candidates/src/features/build_features.py in apply_featurizers(criterion, properties, mpdr, featurizerObject)
#      17         df_portion = mpdr.get_dataframe(criteria=criterion, properties=properties)
#      18         print(df_portion)
# ---> 19         df_portion = featurizerObject.featurize(df_portion)#BandFeaturizer().featurize_dataframe(df, col_id="bandstructure",ignore_errors=True)
#      20         return df_portion
#      21
#
# ~/Dokumenter/masterprosjekt/predicting-solid-state-qubit-candidates/src/features/featurizer.py in featurize(self, df)
#      77         #df_structure      = self.featurize_structure(df)
#      78         #df_site           = self.featurize_site(df)
# ---> 79         df_dos            = self.featurize_dos(df)
#      80         df_band_structure = self.featurize_bandstructure(df)
#      81         #df_dos.to_csv("df_dos.csv")
#
# ~/Dokumenter/masterprosjekt/predicting-solid-state-qubit-candidates/src/features/featurizeAll.py in featurize_dos(self, df)
#     200         """
#     201
# --> 202         df = super().featurize_dos(df)
#     203
#     204         hotencodeColumns = ["DOSFeaturizer|vbm_specie_1","DOSFeaturizer|cbm_specie_1"]
#
# ~/Dokumenter/masterprosjekt/predicting-solid-state-qubit-candidates/src/features/featurizer.py in featurize_dos(self, df)
#     199                 df, "dos", multiindex=True, ignore_errors=True
#     200             )
# --> 201         df = df.replace([np.inf, -np.inf, np.nan], 0)
#     202         df = df.rename(columns={'Input Data': ''})
#     203         df.columns = df.columns.map('|'.join).str.strip('|')
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4519         method="pad",
#    4520     ):
# -> 4521         return super().replace(
#    4522             to_replace=to_replace,
#    4523             value=value,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6887                         f"Expecting {len(to_replace)} got {len(value)} "
#    6888                     )
# -> 6889                 new_data = self._mgr.replace_list(
#    6890                     src_list=to_replace,
#    6891                     dest_list=value,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/internals/managers.py in replace_list(self, src_list, dest_list, inplace, regex)
#     662         inplace = validate_bool_kwarg(inplace, "inplace")
#     663
# --> 664         bm = self.apply(
#     665             "_replace_list",
#     666             src_list=src_list,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     425                     applied = b.apply(f, **kwargs)
#     426                 else:
# --> 427                     applied = getattr(b, f)(**kwargs)
#     428             except (TypeError, NotImplementedError):
#     429                 if not ignore_failures:
#
# ~/.local/lib/python3.8/site-packages/pandas/core/internals/blocks.py in _replace_list(self, src_list, dest_list, inplace, regex)
#     886             # in order to avoid repeating the same computations
#     887             mask = ~isna(self.values)
# --> 888             masks = [comp(s[0], mask, regex) for s in pairs]
#     889         else:
#     890             # GH#38086 faster if we know we dont need to check for regex
#
# ~/.local/lib/python3.8/site-packages/pandas/core/internals/blocks.py in <listcomp>(.0)
#     886             # in order to avoid repeating the same computations
#     887             mask = ~isna(self.values)
# --> 888             masks = [comp(s[0], mask, regex) for s in pairs]
#     889         else:
#     890             # GH#38086 faster if we know we dont need to check for regex
#
# ~/.local/lib/python3.8/site-packages/pandas/core/internals/blocks.py in comp(s, mask, regex)
#     880
#     881             s = maybe_box_datetimelike(s)
# --> 882             return compare_or_regex_search(self.values, s, regex, mask)
#     883
#     884         if self.is_object:
#
# ~/.local/lib/python3.8/site-packages/pandas/core/array_algos/replace.py in compare_or_regex_search(a, b, regex, mask)
#      88         result = tmp
#      89
# ---> 90     _check_comparison_types(result, a, b)
#      91     return result
#      92
#
# ~/.local/lib/python3.8/site-packages/pandas/core/array_algos/replace.py in _check_comparison_types(result, a, b)
#      53                 type_names[0] = f"ndarray(dtype={a.dtype})"
#      54
# ---> 55             raise TypeError(
#      56                 f"Cannot compare types {repr(type_names[0])} and {repr(type_names[1])}"
#      57             )
#
# TypeError: Cannot compare types 'ndarray(dtype=object)' and 'float'

# %%
df

# %%
df = df.reset_index()
df

# %% [markdown]
# # Add together all contributions

# %%
MP_electronic_featurized = MP_electronic_featurized.join(MP_oxidation_featurized.set_index('material_id'), on='material_id')

# %%
MP_ALL_featurized = MP_rest_of_featurizers.join(MP_oxidation_featurized.set_index('material_id'), on='material_id')

# %%
MP_ALL_featurized

# %%
ALL = pd.concat([MP_ALL_featurized,df])

# %%
ALL = sortByMPID(ALL)

# %%
ALL

# %% [markdown]
# ## Sette på ny som er bra for alle. Nå er det godt system.

# %% [markdown]
# # Add band gap from other databases

# %%
bandgaps = pd.read_pickle(data_dir / "interim" / "bandgaps.pkl")
bandgaps

# %%
ALL = ALL.join(bandgaps.set_index('material_id'), on='material_id')
ALL

# %%
ALL.to_pickle(data_dir / "interim" / "featurized" / "featurizedData.pkl")
