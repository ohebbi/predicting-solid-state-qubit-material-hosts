# %% [markdown]
# # 06-post-analysis
#
# How can we verify if the trained models are correct in their predictions?
#
# One way is to verify against known candidates.

# %%
import sys
sys.path.insert(0, "../")

import pandas as pd
from pathlib import Path

data_dir = Path.cwd().parent.parent / "data"
models_dir = Path.cwd().parent.parent / "models" 

print("Current data directory {}".format(data_dir))
# Out:
# Current data directory /home/oliver/Dokumenter/masterprosjekt/predicting-solid-state-qubit-candidates/data

# %%
known_candidates = ["C", "Si", "SiGe", "AlN", "GaN",
                   "AlP", "GaP", "AlAs", "ZnO", "ZnS", "ZnSe", "ZnTe", "CdS"]
QD_2D_candidates = ["BN", "MoS2", "WSe2", #2D
                    "LnAs" #QD
                   ]

# %%
InsertApproach = "03-brute-approach"

# %% [markdown]
# ## Training set
# How many entries in our training set consists of known candidates?

# %%
trainingSet   = pd.read_pickle(data_dir / InsertApproach / "processed" / "trainingSet.pkl")

# %%
trainingSet[["full_formula", "pretty_formula", "candidate"]][trainingSet["pretty_formula"].isin(known_candidates)]
# Out:
#     full_formula pretty_formula  candidate
# 1             C8              C        1.0
# 2             C4              C        1.0
# 3             C2              C        1.0
# 4            Si2             Si        1.0
# 5            Si4             Si        1.0
# ..           ...            ...        ...
# 324          C48              C        1.0
# 325         Si68             Si        1.0
# 327        Si106             Si        1.0
# 331         Si46             Si        1.0
# 332          C20              C        1.0
#
# [155 rows x 3 columns]

# %%
trainingSet[["full_formula", "pretty_formula", "candidate"]][trainingSet["pretty_formula"].isin(QD_2D_candidates)]
# Out:
# Empty DataFrame
# Columns: [full_formula, pretty_formula, candidate]
# Index: []

# %% [markdown]
# ## Test set
# How many entries in our test set consists of known candidates?

# %%
Summary = pd.read_pickle(models_dir / InsertApproach / "summary" / "summary.pkl")
Summary.shape
# Out:
# (24871, 9)

# %%
Summary[Summary["pretty_formula"].isin(known_candidates)] #Not present here since they are in training data
# Out:
# Empty DataFrame
# Columns: [material_id, full_formula, pretty_formula, LOG , LOG Prob, RF , RF Prob, GB , GB Prob]
# Index: []

# %%
Summary[Summary["pretty_formula"].isin(QD_2D_candidates)]
# Out:
#       material_id full_formula pretty_formula  LOG   LOG Prob  RF    RF Prob  \
# 378        mp-344         B4N4             BN   0.0  0.409442  0.0  0.430622
# 477        mp-984         B2N2             BN   1.0  0.715726  0.0  0.497803
# 546       mp-1434        Mo1S2           MoS2   0.0  0.004980  0.0  0.338832
# 574       mp-1599         B4N4             BN   0.0  0.104836  0.0  0.423476
# 577       mp-1639         B1N1             BN   1.0  0.995763  1.0  0.523502
# 604       mp-1821        W2Se4           WSe2   0.0  0.005368  0.0  0.380073
# 723       mp-2653         B2N2             BN   1.0  0.990063  0.0  0.451528
# 747       mp-2815        Mo2S4           MoS2   0.0  0.005491  0.0  0.387864
# 2312      mp-7991         B2N2             BN   1.0  0.783444  0.0  0.494176
# 3428     mp-13151         B4N4             BN   1.0  0.848989  0.0  0.471088
# 14589   mp-569655         B4N4             BN   0.0  0.368652  0.0  0.373068
# 15466   mp-604884         B2N2             BN   1.0  0.717234  0.0  0.428711
# 15828   mp-629015         B2N2             BN   1.0  0.801067  0.0  0.461383
# 16230   mp-644751         B4N4             BN   1.0  0.586463  0.0  0.436196
# 16977   mp-685145         B1N1             BN   1.0  0.846771  0.0  0.464695
# 19353  mp-1018809        Mo2S4           MoS2   0.0  0.004640  0.0  0.407644
# 19647  mp-1060281         B1N1             BN   1.0  0.716329  0.0  0.485677
# 19734  mp-1077506         B3N3             BN   0.0  0.445310  0.0  0.413997
#
#        GB    GB Prob
# 378    0.0  0.386184
# 477    1.0  0.600450
# 546    0.0  0.074581
# 574    0.0  0.204804
# 577    1.0  0.811772
# 604    0.0  0.219349
# 723    1.0  0.512883
# 747    0.0  0.091076
# 2312   0.0  0.384015
# 3428   1.0  0.726655
# 14589  0.0  0.245727
# 15466  0.0  0.283838
# 15828  0.0  0.386641
# 16230  0.0  0.441367
# 16977  0.0  0.160978
# 19353  0.0  0.131623
# 19647  0.0  0.124450
# 19734  0.0  0.340431

# %% [markdown]
# ## How many entries does the models agree on?

# %%
"""
Summary[(Summary["RF "] == 1) & 
        (Summary["RF under"] == 1) & 
        (Summary["RF over"] == 1) & 
        (Summary["RF both"] == 1) & 
        (Summary["GB "] == 1) & 
        (Summary["GB under"] == 1) & 
        (Summary["GB over"] == 1) & 
        (Summary["GB both"] == 1)]
"""
Summary[(Summary["LOG "] == 1) & 
        (Summary["RF "] == 1) & 
        (Summary["GB "] == 1)]
# Out:
#       material_id full_formula pretty_formula  LOG   LOG Prob  RF    RF Prob  \
# 346        mp-160          B12              B   1.0  0.930093  1.0  0.664624
# 361        mp-252       Be1Te1           BeTe   1.0  0.866632  1.0  0.510610
# 416        mp-563         C6N8           C3N4   1.0  0.673539  1.0  0.512918
# 422        mp-624       B12As2           B6As   1.0  0.561764  1.0  0.567237
# 469        mp-938       Ge1Te1           GeTe   1.0  0.878827  1.0  0.538007
# ...           ...          ...            ...   ...       ...  ...       ...
# 22739  mp-1196803     C256Cl16          C16Cl   1.0  0.976131  1.0  0.595760
# 23062  mp-1197923       C122O4          C61O2   1.0  0.989395  1.0  0.720099
# 23097  mp-1198022         Ge34             Ge   1.0  0.999354  1.0  0.555729
# 23280  mp-1198656          B40              B   1.0  0.928294  1.0  0.506650
# 24608  mp-1203368     Zn48As32         Zn3As2   1.0  0.561588  1.0  0.552270
#
#        GB    GB Prob
# 346    1.0  0.861174
# 361    1.0  0.718718
# 416    1.0  0.639686
# 422    1.0  0.693724
# 469    1.0  0.695407
# ...    ...       ...
# 22739  1.0  0.893560
# 23062  1.0  0.958133
# 23097  1.0  0.923578
# 23280  1.0  0.919275
# 24608  1.0  0.506546
#
# [111 rows x 9 columns]
