# %% [markdown]
# # 06-post-analysis
#
# How can we verify if the trained models are correct in their predictions?
#
# One way is to verify against known candidates.

# %%
import sys
sys.path.insert(0, "../")

import pandas as pd
from pathlib import Path

data_dir = Path.cwd().parent.parent.parent / "data"
models_dir = Path.cwd().parent.parent.parent / "models" 

print("Current data directory {}".format(data_dir))
# Out:
# Current data directory /home/oliver/Dokumenter/masterprosjekt/predicting-solid-state-qubit-candidates/data

# %%
known_candidates = ["C", "Si", "SiGe", "AlN", "GaN",
                   "AlP", "GaP", "AlAs", "ZnO", "ZnS", "ZnSe", "ZnTe", "CdS"]
QD_2D_candidates = ["BN", "MoS2", "WSe2", #2D
                    "LnAs" #QD
                   ]

# %%
InsertApproach = "03-brute-approach"
numberOfPrincipalComponents = 2

# %% [markdown]
# ## Training set
# How many entries in our training set consists of known candidates?

# %%
trainingSet   = pd.read_pickle(data_dir / InsertApproach / "processed" / "trainingSet.pkl")

# %%
trainingSet[["full_formula", "pretty_formula", "candidate"]][trainingSet["pretty_formula"].isin(known_candidates)]
# Out:
#     full_formula pretty_formula  candidate
# 1             C8              C        1.0
# 2             C4              C        1.0
# 3             C2              C        1.0
# 4            Si2             Si        1.0
# 5            Si4             Si        1.0
# ..           ...            ...        ...
# 324          C48              C        1.0
# 325         Si68             Si        1.0
# 327        Si106             Si        1.0
# 331         Si46             Si        1.0
# 332          C20              C        1.0
#
# [155 rows x 3 columns]

# %%
trainingSet[["full_formula", "pretty_formula", "candidate"]][trainingSet["pretty_formula"].isin(QD_2D_candidates)]
# Out:
# Empty DataFrame
# Columns: [full_formula, pretty_formula, candidate]
# Index: []

# %% [markdown]
# ## Test set
# How many entries in our test set consists of known candidates?

# %%
Summary = pd.read_pickle(models_dir / InsertApproach /  "summary" / Path("PCA-" + str(numberOfPrincipalComponents) + "-" + "summary.pkl"))
Summary.shape
# Out:
# (24871, 9)

# %%
Summary[Summary["pretty_formula"].isin(known_candidates)]
# Out:
# Empty DataFrame
# Columns: [material_id, full_formula, pretty_formula, LOG , LOG Prob, RF , RF Prob, GB , GB Prob]
# Index: []

# %%
Summary[Summary["pretty_formula"].isin(QD_2D_candidates)]
# Out:
#       material_id full_formula pretty_formula  LOG   LOG Prob  RF    RF Prob  \
# 378        mp-344         B4N4             BN   0.0  0.365134  0.0  0.314532
# 477        mp-984         B2N2             BN   0.0  0.394710  0.0  0.314532
# 546       mp-1434        Mo1S2           MoS2   1.0  0.548509  0.0  0.464836
# 574       mp-1599         B4N4             BN   0.0  0.063371  0.0  0.314532
# 577       mp-1639         B1N1             BN   1.0  0.830858  1.0  0.628596
# 604       mp-1821        W2Se4           WSe2   1.0  0.607618  0.0  0.332671
# 723       mp-2653         B2N2             BN   1.0  0.838327  1.0  0.628596
# 747       mp-2815        Mo2S4           MoS2   0.0  0.465134  0.0  0.414694
# 2312      mp-7991         B2N2             BN   0.0  0.298398  0.0  0.314532
# 3428     mp-13151         B4N4             BN   1.0  0.714732  1.0  0.628596
# 14589   mp-569655         B4N4             BN   0.0  0.234385  0.0  0.314532
# 15466   mp-604884         B2N2             BN   0.0  0.373397  0.0  0.314532
# 15828   mp-629015         B2N2             BN   0.0  0.414287  0.0  0.314532
# 16230   mp-644751         B4N4             BN   1.0  0.663510  1.0  0.628596
# 16977   mp-685145         B1N1             BN   0.0  0.439579  0.0  0.314532
# 19353  mp-1018809        Mo2S4           MoS2   1.0  0.595046  1.0  0.500184
# 19647  mp-1060281         B1N1             BN   1.0  0.553617  0.0  0.299761
# 19734  mp-1077506         B3N3             BN   1.0  0.589246  1.0  0.628596
#
#        GB    GB Prob
# 378    0.0  0.033660
# 477    0.0  0.053649
# 546    0.0  0.351214
# 574    0.0  0.109615
# 577    1.0  0.983385
# 604    0.0  0.065180
# 723    1.0  0.983385
# 747    1.0  0.514803
# 2312   0.0  0.080576
# 3428   1.0  0.990231
# 14589  0.0  0.080576
# 15466  0.0  0.070747
# 15828  0.0  0.070747
# 16230  1.0  0.990231
# 16977  0.0  0.042559
# 19353  1.0  0.886274
# 19647  0.0  0.053649
# 19734  1.0  0.990231

# %% [markdown]
# ## How many entries does the models agree on?

# %%
Summary[(Summary["RF "] == 1) & 
        (Summary["GB "] == 1) & 
        (Summary["LOG "] == 1)]
# Out:
#       material_id   full_formula pretty_formula  LOG   LOG Prob  RF   \
# 334         mp-14            Se3             Se   1.0  0.739504  1.0
# 340        mp-111            Ne1             Ne   1.0  0.841726  1.0
# 342        mp-137           Ge12             Ge   1.0  0.876169  1.0
# 345        mp-157             P4              P   1.0  0.742847  1.0
# 346        mp-160            B12              B   1.0  0.577683  1.0
# ...           ...            ...            ...   ...       ...  ...
# 25181  mp-1244594    La8Mn2S12O2       La4MnS6O   1.0  0.681421  1.0
# 25187  mp-1277483  Li4La16Co4O32      LiLa4CoO8   1.0  0.579077  1.0
# 25189  mp-1288517    La4Fe4As4O4        LaFeAsO   1.0  0.746467  1.0
# 25191  mp-1289745   Ba4Fe2Mo2O12      Ba2FeMoO6   1.0  0.796140  1.0
# 25197  mp-1299874  Li4La16Co4O32      LiLa4CoO8   1.0  0.582799  1.0
#
#         RF Prob  GB    GB Prob
# 334    0.549479  1.0  0.974128
# 340    0.833336  1.0  0.978457
# 342    0.793089  1.0  0.979288
# 345    0.715649  1.0  0.886274
# 346    0.548921  1.0  0.867509
# ...         ...  ...       ...
# 25181  0.697035  1.0  0.886274
# 25187  0.653459  1.0  0.704526
# 25189  0.824277  1.0  0.927284
# 25191  0.679065  1.0  0.579124
# 25197  0.653459  1.0  0.704526
#
# [3060 rows x 9 columns]
