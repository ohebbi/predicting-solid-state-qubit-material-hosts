# %% [markdown]
# # 06-post-analysis
#
# How can we verify if the trained models are correct in their predictions?
#
# One way is to verify against known candidates.

# %%
import sys
sys.path.insert(0, "../")

import pandas as pd
from pathlib import Path

data_dir = Path.cwd().parent.parent.parent / "data"
models_dir = Path.cwd().parent.parent.parent / "models" 

print("Current data directory {}".format(data_dir))
# Out:
# Current data directory /home/oliver/Dokumenter/masterprosjekt/predicting-solid-state-qubit-candidates/data

# %%
known_candidates = ["C", "Si", "SiGe", "AlN", "GaN",
                   "AlP", "GaP", "AlAs", "ZnO", "ZnS", "ZnSe", "ZnTe", "CdS"]
QD_2D_candidates = ["BN", "MoS2", "WSe2", #2D
                    "LnAs" #QD
                   ]

# %%
InsertApproach = "02-determined-approach"
numberOfPrincipalComponents = 2

# %% [markdown]
# ## Training set
# How many entries in our training set consists of known candidates?

# %%
trainingSet   = pd.read_pickle(data_dir / InsertApproach / "processed" / "trainingSet.pkl")

# %%
trainingSet[["full_formula", "pretty_formula", "candidate"]][trainingSet["pretty_formula"].isin(known_candidates)]
# Out:
#      full_formula pretty_formula  candidate
# 3              C8              C        1.0
# 5              C4              C        1.0
# 6              C2              C        1.0
# 13            Si2             Si        1.0
# 16            Si4             Si        1.0
# 17             C2              C        1.0
# 47          Al2N2            AlN        0.0
# 61          Ga2N2            GaN        0.0
# 62          Ga1N1            GaN        1.0
# 79         Zn1Se1           ZnSe        1.0
# 86          Al1N1            AlN        1.0
# 104         Al1P1            AlP        1.0
# 118         Al1N1            AlN        1.0
# 139         Zn1O1            ZnO        1.0
# 150        Al1As1           AlAs        1.0
# 152        Zn1Te1           ZnTe        1.0
# 155         Zn1O1            ZnO        1.0
# 167         Ga1P1            GaP        1.0
# 192         Ga1N1            GaN        1.0
# 528         Al2P2            AlP        0.0
# 529        Al2As2           AlAs        0.0
# 530         Ga2P2            GaP        0.0
# 594         Zn1S1            ZnS        1.0
# 658         Zn1O1            ZnO        1.0
# 659         Al2N2            AlN        1.0
# 733          Si34             Si        1.0
# 1668           C4              C        1.0
# 1670           C8              C        1.0
# 1675          C14              C        1.0
# 1680       Zn2Se2           ZnSe        1.0
# 1689           C8              C        1.0
# 1822           C8              C        1.0
# 1823          C12              C        1.0
# 1830          C16              C        1.0
# 1855          C60              C        1.0
# 1952          C60              C        1.0
# 2018          C60              C        1.0
# 2028         C140              C        1.0
# 2084         Si46             Si        1.0
# 2098          Si4             Si        1.0
# 2106        Ga2N2            GaN        1.0
# 2108           C4              C        1.0
# 2145        Ga2P2            GaP        1.0
# 2267           C8              C        1.0
# 2293           C8              C        1.0
# 2301         Si12             Si        1.0
# 2310          C12              C        1.0
# 2315          C12              C        1.0
# 2416          C16              C        1.0
# 2519         C240              C        1.0
# 2525         Si40             Si        1.0
# 2572         Si82             Si        1.0
# 2588         Si41             Si        1.0
# 2596        Si232             Si        1.0
# 2622         Si58             Si        1.0
# 2633          C48              C        1.0
# 2636         Si68             Si        1.0
# 2645         Si46             Si        1.0
# 2664          C20              C        1.0

# %%
trainingSet[["full_formula", "pretty_formula", "candidate"]][trainingSet["pretty_formula"].isin(QD_2D_candidates)]
# Out:
#      full_formula pretty_formula  candidate
# 27           B4N4             BN        0.0
# 69           B2N2             BN        1.0
# 112          B4N4             BN        0.0
# 115          B1N1             BN        1.0
# 124         W2Se4           WSe2        1.0
# 180          B2N2             BN        0.0
# 190         Mo2S4           MoS2        1.0
# 482          B2N2             BN        1.0
# 657          B4N4             BN        1.0
# 1678         B4N4             BN        1.0
# 1816         B2N2             BN        1.0
# 1852         B2N2             BN        1.0
# 1895         B4N4             BN        1.0
# 2040         B1N1             BN        0.0
# 2151        Mo2S4           MoS2        1.0
# 2232         B1N1             BN        1.0
# 2252         B3N3             BN        0.0

# %% [markdown]
# ## Test set
# How many entries in our test set consists of known candidates?

# %%
Summary = pd.read_pickle(models_dir / InsertApproach /  "summary" / Path("PCA-" + str(numberOfPrincipalComponents) + "-" + "summary.pkl"))
Summary.shape
# Out:
# (22576, 9)

# %%
Summary[Summary["pretty_formula"].isin(known_candidates)]
# Out:
#       material_id full_formula pretty_formula  LOG   LOG Prob  RF    RF Prob  \
# 2728       mp-370        Cd1S1            CdS   1.0  0.911533  1.0  0.812360
# 2730       mp-380       Zn2Se2           ZnSe   1.0  0.876508  1.0  0.922988
# 2757       mp-672        Cd2S2            CdS   1.0  0.872519  1.0  0.922988
# 2888      mp-2133        Zn2O2            ZnO   1.0  0.962533  1.0  0.922988
# 2919      mp-2469        Cd1S1            CdS   1.0  0.884853  1.0  0.922988
# ...           ...          ...            ...   ...       ...  ...       ...
# 24282  mp-1201781      Zn18S18            ZnS   1.0  0.890737  1.0  0.922988
# 24344  mp-1202023      Zn18S18            ZnS   1.0  0.888831  1.0  0.922988
# 24385  mp-1202182      Zn18S18            ZnS   1.0  0.888553  1.0  0.922988
# 24587  mp-1202959      Zn18S18            ZnS   1.0  0.888672  1.0  0.922988
# 24876  mp-1204046        Si106             Si   1.0  0.854176  1.0  0.919195
#
#        GB    GB Prob
# 2728   1.0  0.908514
# 2730   1.0  0.896668
# 2757   1.0  0.891962
# 2888   1.0  0.965303
# 2919   1.0  0.896668
# ...    ...       ...
# 24282  1.0  0.938300
# 24344  1.0  0.938300
# 24385  1.0  0.938300
# 24587  1.0  0.938300
# 24876  1.0  0.915223
#
# [96 rows x 9 columns]

# %%
Summary[Summary["pretty_formula"].isin(QD_2D_candidates)]
# Out:
#      material_id full_formula pretty_formula  LOG   LOG Prob  RF    RF Prob  \
# 2833     mp-1434        Mo1S2           MoS2   1.0  0.870943  1.0  0.922988
#
#       GB    GB Prob
# 2833  1.0  0.933119

# %% [markdown]
# ## How many entries does the models agree on?

# %%
Summary[(Summary["RF "] == 1) & 
        (Summary["GB "] == 1) & 
        (Summary["LOG "] == 1)]
# Out:
#       material_id full_formula pretty_formula  LOG   LOG Prob  RF    RF Prob  \
# 2700    mvc-12905        Fe4O8           FeO2   1.0  0.937136  1.0  0.922988
# 2701       mp-111          Ne1             Ne   1.0  0.921445  1.0  0.922988
# 2702       mp-157           P4              P   1.0  0.912427  1.0  0.922988
# 2703       mp-181        K3Ga9           KGa3   1.0  0.807047  1.0  0.916091
# 2704       mp-189       Si4Ru4           SiRu   1.0  0.935354  1.0  0.922988
# ...           ...          ...            ...   ...       ...  ...       ...
# 25271  mp-1539137     Rb1Cr5S8        RbCr5S8   1.0  0.878796  1.0  0.922988
# 25272  mp-1541522      Bi2P2O8          BiPO4   1.0  0.928320  1.0  0.922988
# 25273  mp-1541714    Cs3As2Cl9      Cs3As2Cl9   1.0  0.814969  1.0  0.916091
# 25274  mp-1542038    Cs2Sn2Se6        CsSnSe3   1.0  0.688875  1.0  0.886079
# 25275  mp-1542939   Ba1Mo1P2O8     BaMo(PO4)2   1.0  0.938595  1.0  0.922988
#
#        GB    GB Prob
# 2700   1.0  0.952595
# 2701   1.0  0.941121
# 2702   1.0  0.944097
# 2703   1.0  0.916549
# 2704   1.0  0.949524
# ...    ...       ...
# 25271  1.0  0.933119
# 25272  1.0  0.939623
# 25273  1.0  0.920663
# 25274  1.0  0.814304
# 25275  1.0  0.952595
#
# [19966 rows x 9 columns]
