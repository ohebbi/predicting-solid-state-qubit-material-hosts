# %% [markdown]
# # 06-post-analysis
#
# How can we verify if the trained models are correct in their predictions?
#
# One way is to verify against known candidates.

# %%
import sys
sys.path.insert(0, "../")

import pandas as pd
from pathlib import Path
from src.visualization import visualize

data_dir = Path.cwd().parent.parent.parent / "data"
models_dir = Path.cwd().parent.parent.parent / "models" 

print("Current data directory {}".format(data_dir))

# Optional: Load the "autoreload" extension so that code can change
# %load_ext autoreload

#OPTIONAL: Always reload modules so that as you change code in src, it gets loaded
# %autoreload 2
# Out:
# Current data directory /Users/oliverhebnes/Documents/predicting-solid-state-qubit-material-hosts/data

# %%
known_candidates = ["SiC","SiGe", "C", "Si",
                         "GaN", "GaAs", "AlN", "ZnS", "ZnSe", "ZnO",
                         "AlP", "GaP", "AlAs", "ZnTe", "CdS"
                    ]
QD_2D_candidates = ["BN", "MoS2", "WSe2", "WS2",#2D
                    "InAs" #QD
                   ]

# %%
title = "Extended Ferrenti summary"
InsertApproach = "02-extended-ferrenti-approach"
numberOfPrincipalComponents = 176

# %% [markdown]
# ## Training set

# %%
trainingSet   = pd.read_pickle(data_dir / InsertApproach / "processed" / "trainingData.pkl")
trainingTarget   = pd.read_pickle(data_dir / InsertApproach / "processed" / "trainingTarget.pkl")
trainingSet["candidate"] = trainingTarget

# %%
trainingSet
# Out:
#      material_id  full_formula  AtomicOrbitals|HOMO_character  \
# 0           mp-7            S6                            2.0
# 1          mp-25            N8                            2.0
# 2          mp-47            C4                            2.0
# 3          mp-66            C2                            2.0
# 4          mp-77           S32                            2.0
# ...          ...           ...                            ...
# 2614  mp-1275839  Co4Bi24S8O64                            3.0
# 2615  mp-1291058  Sr4Mn2Mo2O12                            3.0
# 2616  mp-1291630       Fe12O16                            3.0
# 2617  mp-1298346     Sr8Co4O16                            3.0
# 2618  mp-1539137      Rb1Cr5S8                            3.0
#
#       AtomicOrbitals|HOMO_element  AtomicOrbitals|HOMO_energy  \
# 0                              16                   -0.261676
# 1                               7                   -0.266297
# 2                               6                   -0.199186
# 3                               6                   -0.199186
# 4                              16                   -0.261676
# ...                           ...                         ...
# 2614                           27                   -0.322368
# 2615                           25                   -0.266540
# 2616                           26                   -0.295049
# 2617                           27                   -0.322368
# 2618                           24                   -0.118123
#
#       AtomicOrbitals|LUMO_character  AtomicOrbitals|LUMO_element  \
# 0                               2.0                           16
# 1                               2.0                            7
# 2                               2.0                            6
# 3                               2.0                            6
# 4                               2.0                           16
# ...                             ...                          ...
# 2614                            3.0                           27
# 2615                            3.0                           25
# 2616                            3.0                           26
# 2617                            3.0                           27
# 2618                            3.0                           24
#
#       AtomicOrbitals|LUMO_energy  \
# 0                      -0.261676
# 1                      -0.266297
# 2                      -0.199186
# 3                      -0.199186
# 4                      -0.261676
# ...                          ...
# 2614                   -0.322368
# 2615                   -0.266540
# 2616                   -0.295049
# 2617                   -0.322368
# 2618                   -0.118123
#
#       AtomicPackingEfficiency|dist from 1 clusters |APE| < 0.010  \
# 0                                              1.000000
# 1                                              1.000000
# 2                                              1.000000
# 3                                              1.000000
# 4                                              1.000000
# ...                                                 ...
# 2614                                           0.034641
# 2615                                           0.052116
# 2616                                           0.091832
# 2617                                           0.057864
# 2618                                           0.033111
#
#       AtomicPackingEfficiency|dist from 3 clusters |APE| < 0.010  ...  \
# 0                                              1.000000           ...
# 1                                              1.000000           ...
# 2                                              1.000000           ...
# 3                                              1.000000           ...
# 4                                              1.000000           ...
# ...                                                 ...           ...
# 2614                                           0.052087           ...
# 2615                                           0.058661           ...
# 2616                                           0.135247           ...
# 2617                                           0.095274           ...
# 2618                                           0.074127           ...
#
#       AFLOWML|ml_agl_thermal_conductivity_300K  \
# 0                                        3.440
# 1                                        3.211
# 2                                        3.223
# 3                                        4.279
# 4                                        2.637
# ...                                        ...
# 2614                                     2.690
# 2615                                     2.749
# 2616                                     2.841
# 2617                                     2.725
# 2618                                     2.708
#
#       AFLOWML|ml_agl_thermal_expansion_300K  MP|spacegroup.number  \
# 0                                  0.000070                   148
# 1                                  0.000063                   205
# 2                                  0.000086                   194
# 3                                  0.000086                   227
# 4                                  0.000070                    70
# ...                                     ...                   ...
# 2614                               0.000052                     3
# 2615                               0.000060                     1
# 2616                               0.000060                     5
# 2617                               0.000061                     4
# 2618                               0.000061                     8
#
#       MP|total_magnetization  MP|nelements  MP|efermi   MP|Eg  AFLOWML|Eg  \
# 0                   0.000034             1   0.348895  2.4881       2.490
# 1                   0.000000             1  -6.929356  7.4564       7.304
# 2                   0.000000             1   9.983070  3.3395       3.166
# 3                   0.000000             1   9.614764  4.3387       3.593
# 4                   0.000000             1  -0.543939  2.7125       2.281
# ...                      ...           ...        ...     ...         ...
# 2614                0.000351             4   3.917413  2.3186       2.156
# 2615                0.992766             4   3.987258  0.8079       0.000
# 2616                6.504784             2   4.184540  0.1221       0.000
# 2617                0.000485             3   2.323107  0.5907       0.000
# 2618               11.000000             3   4.879709  0.3523       0.584
#
#       MP|Polar SG  candidate
# 0               0        1.0
# 1               0        1.0
# 2               0        1.0
# 3               0        1.0
# 4               0        1.0
# ...           ...        ...
# 2614            1        0.0
# 2615            1        0.0
# 2616            1        0.0
# 2617            1        0.0
# 2618            1        0.0
#
# [2619 rows x 680 columns]

# %%
#trainingSet[["full_formula", "pretty_formula", "candidate"]][trainingSet["pretty_formula"].isin(known_candidates)]

# %% [markdown]
# ## Test set
# How many entries in our test set consists of known candidates?

# %%
Summary = pd.read_pickle(models_dir / InsertApproach /  "summary" / Path("PCA-" + str(numberOfPrincipalComponents) + "-" + "summary.pkl"))
Summary = Summary.reset_index(drop=True)
Summary.shape
# Out:
# (22550, 11)

# %%
Summary[Summary["pretty_formula"].isin(known_candidates)]
# Out:
#       material_id full_formula pretty_formula  LOG   LOG Prob  DT    DT Prob  \
# 3           mp-24           C8              C   1.0  1.000000  1.0  0.758333
# 5          mp-149          Si2             Si   1.0  0.999995  1.0  0.758333
# 7          mp-165          Si4             Si   1.0  0.999968  1.0  0.758333
# 36         mp-370        Cd1S1            CdS   1.0  1.000000  1.0  1.000000
# 37         mp-380       Zn2Se2           ZnSe   1.0  0.980394  1.0  1.000000
# ...           ...          ...            ...   ...       ...  ...       ...
# 22061  mp-1203645          C48              C   1.0  1.000000  1.0  0.977273
# 22101  mp-1203790         Si68             Si   1.0  0.999982  1.0  0.870968
# 22159  mp-1204046        Si106             Si   1.0  0.999762  1.0  0.870968
# 22227  mp-1204356      Si19C19            SiC   1.0  0.992436  1.0  0.758333
# 22489  mp-1205417          C20              C   1.0  1.000000  1.0  0.870968
#
#        RF    RF Prob  GB    GB Prob
# 3      1.0  0.740415  1.0  0.907523
# 5      1.0  0.820862  1.0  0.976041
# 7      1.0  0.807817  1.0  0.969212
# 36     1.0  0.930070  1.0  0.979216
# 37     1.0  0.696693  1.0  0.791644
# ...    ...       ...  ...       ...
# 22061  1.0  0.787981  1.0  0.941765
# 22101  1.0  0.814311  1.0  0.982100
# 22159  1.0  0.856816  1.0  0.985963
# 22227  1.0  0.843997  1.0  0.982537
# 22489  1.0  0.829684  1.0  0.982389
#
# [161 rows x 11 columns]

# %%
Summary[Summary["pretty_formula"].isin(QD_2D_candidates)]
# Out:
#       material_id full_formula pretty_formula  LOG   LOG Prob  DT    DT Prob  \
# 32         mp-344         B4N4             BN   1.0  0.999998  1.0  0.987952
# 161       mp-1434        Mo1S2           MoS2   1.0  0.806114  1.0  0.969697
# 179       mp-1599         B4N4             BN   1.0  0.939817  1.0  0.977273
# 299       mp-2653         B2N2             BN   1.0  0.999945  1.0  1.000000
# 317       mp-2815        Mo2S4           MoS2   1.0  0.998666  1.0  0.969697
# 2059      mp-9813         W1S2            WS2   1.0  0.986849  1.0  0.969697
# 4344     mp-20305       In1As1           InAs   1.0  0.924358  1.0  0.977273
# 12677   mp-569655         B4N4             BN   1.0  1.000000  1.0  0.987952
# 14244   mp-644751         B4N4             BN   1.0  1.000000  1.0  0.758333
# 14918   mp-685145         B1N1             BN   1.0  0.999981  1.0  0.812500
# 17197  mp-1018809        Mo2S4           MoS2   1.0  0.997419  1.0  0.969697
# 17425  mp-1060281         B1N1             BN   1.0  1.000000  0.0  0.000000
# 17499  mp-1077506         B3N3             BN   1.0  0.968857  1.0  0.896552
#
#        RF    RF Prob  GB    GB Prob
# 32     1.0  0.806834  1.0  0.926745
# 161    1.0  0.757886  1.0  0.921849
# 179    1.0  0.801399  1.0  0.935933
# 299    1.0  0.830868  1.0  0.846600
# 317    1.0  0.650360  1.0  0.729442
# 2059   1.0  0.702460  1.0  0.617317
# 4344   1.0  0.770345  1.0  0.817080
# 12677  1.0  0.900695  1.0  0.983571
# 14244  1.0  0.841906  1.0  0.987961
# 14918  1.0  0.926992  1.0  0.990041
# 17197  1.0  0.654595  1.0  0.917386
# 17425  1.0  0.940392  1.0  0.995282
# 17499  1.0  0.727580  1.0  0.853978

# %% [markdown]
# ## How many entries does the models agree on?

# %%
RF_DT_GB_LOG = Summary[(Summary["RF "] == 1) & 
                       (Summary["DT "] == 1) & 
                       (Summary["GB "] == 1) & 
                       (Summary["LOG "] == 1)]

RF_DT_GB_LOG.to_csv(models_dir / InsertApproach / "summary" / "RF_DT_GB_LOG.csv")
RF_DT_GB_LOG
# Out:
#       material_id   full_formula pretty_formula  LOG   LOG Prob  DT   \
# 0       mvc-12905          Fe4O8           FeO2   1.0  0.619261  1.0
# 1           mp-14            Se3             Se   1.0  0.999950  1.0
# 2           mp-19            Te3             Te   1.0  0.997149  1.0
# 3           mp-24             C8              C   1.0  1.000000  1.0
# 4          mp-137           Ge12             Ge   1.0  0.999795  1.0
# ...           ...            ...            ...   ...       ...  ...
# 22537  mp-1277483  Li4La16Co4O32      LiLa4CoO8   1.0  0.634865  1.0
# 22544  mp-1299874  Li4La16Co4O32      LiLa4CoO8   1.0  0.623892  1.0
# 22545  mp-1304797  Sr12In4Ni4O24      Sr3InNiO6   1.0  0.999205  1.0
# 22546  mp-1541522        Bi2P2O8          BiPO4   1.0  0.999992  1.0
# 22549  mp-1542939     Ba1Mo1P2O8     BaMo(PO4)2   1.0  0.912518  1.0
#
#         DT Prob  RF    RF Prob  GB    GB Prob
# 0      0.969697  1.0  0.805296  1.0  0.865425
# 1      0.758333  1.0  0.773990  1.0  0.979370
# 2      0.977273  1.0  0.730251  1.0  0.956867
# 3      0.758333  1.0  0.740415  1.0  0.907523
# 4      0.977273  1.0  0.781682  1.0  0.804625
# ...         ...  ...       ...  ...       ...
# 22537  1.000000  1.0  0.599640  1.0  0.741950
# 22544  1.000000  1.0  0.598835  1.0  0.847202
# 22545  1.000000  1.0  0.782829  1.0  0.860288
# 22546  0.946237  1.0  0.962639  1.0  0.988552
# 22549  0.957447  1.0  0.722989  1.0  0.870427
#
# [9227 rows x 11 columns]

# %%
Summary[(Summary["RF Prob"] > 0.8) & 
        (Summary["DT Prob"] > 0.8) & 
        (Summary["GB Prob"] > 0.8) & 
        (Summary["LOG Prob"] > 0.8)]
# Out:
#       material_id    full_formula pretty_formula  LOG   LOG Prob  DT   \
# 6          mp-157              P4              P   1.0  0.999994  1.0
# 12         mp-216         Sc16O24          Sc2O3   1.0  0.999999  1.0
# 13         mp-226           Fe4S8           FeS2   1.0  0.981889  1.0
# 15         mp-236            S4N4             SN   1.0  0.999999  1.0
# 16         mp-241           Cd1F2           CdF2   1.0  0.999999  1.0
# ...           ...             ...            ...   ...       ...  ...
# 22495  mp-1205442  Zn2Bi12P4O28F4  ZnBi6P2(O7F)2   1.0  0.889833  1.0
# 22506  mp-1206099            Y2O6            YO3   1.0  0.986977  1.0
# 22511  mp-1209868       Nd2Tm6S12      Nd(TmS2)3   1.0  0.993785  1.0
# 22527  mp-1238430       Rb8C16N24         RbC2N3   1.0  0.999993  1.0
# 22546  mp-1541522         Bi2P2O8          BiPO4   1.0  0.999992  1.0
#
#         DT Prob  RF    RF Prob  GB    GB Prob
# 6      0.969697  1.0  0.864496  1.0  0.992550
# 12     1.000000  1.0  0.825681  1.0  0.820456
# 13     0.896552  1.0  0.896988  1.0  0.990180
# 15     0.953975  1.0  0.877742  1.0  0.981670
# 16     0.953975  1.0  0.890070  1.0  0.991457
# ...         ...  ...       ...  ...       ...
# 22495  0.978261  1.0  0.885876  1.0  0.961534
# 22506  0.969697  1.0  0.806334  1.0  0.907515
# 22511  1.000000  1.0  0.909058  1.0  0.976507
# 22527  0.946237  1.0  0.945235  1.0  0.993320
# 22546  0.946237  1.0  0.962639  1.0  0.988552
#
# [3073 rows x 11 columns]

# %%
RF_DT_GB = Summary[(Summary["RF "] == 1) & 
                       (Summary["DT "] == 1) & 
                       (Summary["GB "] == 1)]

RF_DT_GB.to_csv(models_dir / InsertApproach / "summary" / "RF_DT_GB.csv")
RF_DT_GB
# Out:
#       material_id   full_formula pretty_formula  LOG   LOG Prob  DT   \
# 0       mvc-12905          Fe4O8           FeO2   1.0  0.619261  1.0
# 1           mp-14            Se3             Se   1.0  0.999950  1.0
# 2           mp-19            Te3             Te   1.0  0.997149  1.0
# 3           mp-24             C8              C   1.0  1.000000  1.0
# 4          mp-137           Ge12             Ge   1.0  0.999795  1.0
# ...           ...            ...            ...   ...       ...  ...
# 22543  mp-1296711       La2Co2O6         LaCoO3   0.0  0.031129  1.0
# 22544  mp-1299874  Li4La16Co4O32      LiLa4CoO8   1.0  0.623892  1.0
# 22545  mp-1304797  Sr12In4Ni4O24      Sr3InNiO6   1.0  0.999205  1.0
# 22546  mp-1541522        Bi2P2O8          BiPO4   1.0  0.999992  1.0
# 22549  mp-1542939     Ba1Mo1P2O8     BaMo(PO4)2   1.0  0.912518  1.0
#
#         DT Prob  RF    RF Prob  GB    GB Prob
# 0      0.969697  1.0  0.805296  1.0  0.865425
# 1      0.758333  1.0  0.773990  1.0  0.979370
# 2      0.977273  1.0  0.730251  1.0  0.956867
# 3      0.758333  1.0  0.740415  1.0  0.907523
# 4      0.977273  1.0  0.781682  1.0  0.804625
# ...         ...  ...       ...  ...       ...
# 22543  0.953975  1.0  0.686020  1.0  0.844033
# 22544  1.000000  1.0  0.598835  1.0  0.847202
# 22545  1.000000  1.0  0.782829  1.0  0.860288
# 22546  0.946237  1.0  0.962639  1.0  0.988552
# 22549  0.957447  1.0  0.722989  1.0  0.870427
#
# [10791 rows x 11 columns]

# %%
Summary[(Summary["RF Prob"] > 0.75) & 
        (Summary["DT Prob"] > 0.75) & 
        (Summary["GB Prob"] > 0.75)]
# Out:
#       material_id   full_formula pretty_formula  LOG   LOG Prob  DT   \
# 0       mvc-12905          Fe4O8           FeO2   1.0  0.619261  1.0
# 1           mp-14            Se3             Se   1.0  0.999950  1.0
# 4          mp-137           Ge12             Ge   1.0  0.999795  1.0
# 5          mp-149            Si2             Si   1.0  0.999995  1.0
# 6          mp-157             P4              P   1.0  0.999994  1.0
# ...           ...            ...            ...   ...       ...  ...
# 22517  mp-1232408    Cs6In6P8O32   Cs3In3(PO4)4   1.0  0.996807  1.0
# 22527  mp-1238430      Rb8C16N24         RbC2N3   1.0  0.999993  1.0
# 22536  mp-1272351      Ba6Cr4O16       Ba3Cr2O8   0.0  0.000895  1.0
# 22545  mp-1304797  Sr12In4Ni4O24      Sr3InNiO6   1.0  0.999205  1.0
# 22546  mp-1541522        Bi2P2O8          BiPO4   1.0  0.999992  1.0
#
#         DT Prob  RF    RF Prob  GB    GB Prob
# 0      0.969697  1.0  0.805296  1.0  0.865425
# 1      0.758333  1.0  0.773990  1.0  0.979370
# 4      0.977273  1.0  0.781682  1.0  0.804625
# 5      0.758333  1.0  0.820862  1.0  0.976041
# 6      0.969697  1.0  0.864496  1.0  0.992550
# ...         ...  ...       ...  ...       ...
# 22517  0.771429  1.0  0.871451  1.0  0.913762
# 22527  0.946237  1.0  0.945235  1.0  0.993320
# 22536  0.758333  1.0  0.832191  1.0  0.888288
# 22545  1.000000  1.0  0.782829  1.0  0.860288
# 22546  0.946237  1.0  0.962639  1.0  0.988552
#
# [5366 rows x 11 columns]

# %%
Summary[(Summary["RF "] == 1) &  
        (Summary["GB "] == 1)]
# Out:
#       material_id   full_formula pretty_formula  LOG   LOG Prob  DT   \
# 0       mvc-12905          Fe4O8           FeO2   1.0  0.619261  1.0
# 1           mp-14            Se3             Se   1.0  0.999950  1.0
# 2           mp-19            Te3             Te   1.0  0.997149  1.0
# 3           mp-24             C8              C   1.0  1.000000  1.0
# 4          mp-137           Ge12             Ge   1.0  0.999795  1.0
# ...           ...            ...            ...   ...       ...  ...
# 22544  mp-1299874  Li4La16Co4O32      LiLa4CoO8   1.0  0.623892  1.0
# 22545  mp-1304797  Sr12In4Ni4O24      Sr3InNiO6   1.0  0.999205  1.0
# 22546  mp-1541522        Bi2P2O8          BiPO4   1.0  0.999992  1.0
# 22548  mp-1542038      Cs2Sn2Se6        CsSnSe3   1.0  0.705610  0.0
# 22549  mp-1542939     Ba1Mo1P2O8     BaMo(PO4)2   1.0  0.912518  1.0
#
#         DT Prob  RF    RF Prob  GB    GB Prob
# 0      0.969697  1.0  0.805296  1.0  0.865425
# 1      0.758333  1.0  0.773990  1.0  0.979370
# 2      0.977273  1.0  0.730251  1.0  0.956867
# 3      0.758333  1.0  0.740415  1.0  0.907523
# 4      0.977273  1.0  0.781682  1.0  0.804625
# ...         ...  ...       ...  ...       ...
# 22544  1.000000  1.0  0.598835  1.0  0.847202
# 22545  1.000000  1.0  0.782829  1.0  0.860288
# 22546  0.946237  1.0  0.962639  1.0  0.988552
# 22548  0.081967  1.0  0.657713  1.0  0.834916
# 22549  0.957447  1.0  0.722989  1.0  0.870427
#
# [13140 rows x 11 columns]

# %%
Summary[Summary["LOG "]==1]
# Out:
#       material_id   full_formula pretty_formula  LOG   LOG Prob  DT   \
# 0       mvc-12905          Fe4O8           FeO2   1.0  0.619261  1.0
# 1           mp-14            Se3             Se   1.0  0.999950  1.0
# 2           mp-19            Te3             Te   1.0  0.997149  1.0
# 3           mp-24             C8              C   1.0  1.000000  1.0
# 4          mp-137           Ge12             Ge   1.0  0.999795  1.0
# ...           ...            ...            ...   ...       ...  ...
# 22545  mp-1304797  Sr12In4Ni4O24      Sr3InNiO6   1.0  0.999205  1.0
# 22546  mp-1541522        Bi2P2O8          BiPO4   1.0  0.999992  1.0
# 22547  mp-1541714      Cs3As2Cl9      Cs3As2Cl9   1.0  0.668093  1.0
# 22548  mp-1542038      Cs2Sn2Se6        CsSnSe3   1.0  0.705610  0.0
# 22549  mp-1542939     Ba1Mo1P2O8     BaMo(PO4)2   1.0  0.912518  1.0
#
#         DT Prob  RF    RF Prob  GB    GB Prob
# 0      0.969697  1.0  0.805296  1.0  0.865425
# 1      0.758333  1.0  0.773990  1.0  0.979370
# 2      0.977273  1.0  0.730251  1.0  0.956867
# 3      0.758333  1.0  0.740415  1.0  0.907523
# 4      0.977273  1.0  0.781682  1.0  0.804625
# ...         ...  ...       ...  ...       ...
# 22545  1.000000  1.0  0.782829  1.0  0.860288
# 22546  0.946237  1.0  0.962639  1.0  0.988552
# 22547  1.000000  1.0  0.564260  0.0  0.140622
# 22548  0.081967  1.0  0.657713  1.0  0.834916
# 22549  0.957447  1.0  0.722989  1.0  0.870427
#
# [14993 rows x 11 columns]

# %%
generatedData = pd.read_pickle(data_dir / "interim" / "featurized" / "featurized-11-04-2021.pkl")
generatedData = generatedData[~generatedData["material_id"].isin(trainingSet["material_id"])].reset_index(drop=True)

# %%
visualize.visualize_heatmap_of_combinations(Summary)
# Out:
# findfont: Font family ['Palatino Linotype'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Palatino Linotype'] not found. Falling back to DejaVu Sans.
# [1.0, 0.7292069632495164, 0.6402840205849781, 0.6010683343104684, 0.7694870549038662, 0.793173083186763, 0.8559702950947821, 1.0, 1.0, 0.7642900020009338, 0.7794931926258876]
#                   LOG LOG LOG LOG   LOG LOG LOG DT   LOG LOG RF DT   \
# LOG LOG LOG LOG                1.0         0.729207        0.640284
# LOG LOG LOG DT                 1.0         0.729207        0.640284
# LOG LOG RF DT                  1.0         0.729207        0.640284
# LOG RF GB DT                   1.0         0.729207        0.640284
# DT GB DT DT                    1.0         0.729207        0.640284
# DT RF DT DT                    1.0         0.729207        0.640284
# RF RF GB GB                    1.0         0.729207        0.640284
# RF RF RF RF                    1.0         0.729207        0.640284
# GB GB GB GB                    1.0         0.729207        0.640284
# GB LOG LOG LOG                 1.0         0.729207        0.640284
# RF LOG LOG LOG                 1.0         0.729207        0.640284
#
#                   LOG RF GB DT   DT GB DT DT   DT RF DT DT   RF RF GB GB   \
# LOG LOG LOG LOG        0.601068      0.769487      0.793173       0.85597
# LOG LOG LOG DT         0.601068      0.769487      0.793173       0.85597
# LOG LOG RF DT          0.601068      0.769487      0.793173       0.85597
# LOG RF GB DT           0.601068      0.769487      0.793173       0.85597
# DT GB DT DT            0.601068      0.769487      0.793173       0.85597
# DT RF DT DT            0.601068      0.769487      0.793173       0.85597
# RF RF GB GB            0.601068      0.769487      0.793173       0.85597
# RF RF RF RF            0.601068      0.769487      0.793173       0.85597
# GB GB GB GB            0.601068      0.769487      0.793173       0.85597
# GB LOG LOG LOG         0.601068      0.769487      0.793173       0.85597
# RF LOG LOG LOG         0.601068      0.769487      0.793173       0.85597
#
#                   RF RF RF RF   GB GB GB GB   GB LOG LOG LOG   RF LOG LOG LOG
# LOG LOG LOG LOG            1.0           1.0          0.76429         0.779493
# LOG LOG LOG DT             1.0           1.0          0.76429         0.779493
# LOG LOG RF DT              1.0           1.0          0.76429         0.779493
# LOG RF GB DT               1.0           1.0          0.76429         0.779493
# DT GB DT DT                1.0           1.0          0.76429         0.779493
# DT RF DT DT                1.0           1.0          0.76429         0.779493
# RF RF GB GB                1.0           1.0          0.76429         0.779493
# RF RF RF RF                1.0           1.0          0.76429         0.779493
# GB GB GB GB                1.0           1.0          0.76429         0.779493
# GB LOG LOG LOG             1.0           1.0          0.76429         0.779493
# RF LOG LOG LOG             1.0           1.0          0.76429         0.779493

# %%
Summary = Summary[Summary["material_id"].isin(generatedData.material_id)].reset_index(drop=True)
generatedData = generatedData[generatedData["material_id"].isin(Summary.material_id)].reset_index(drop=True)
abbreviations = ["LOG ", "DT ", "RF ", "GB "]
for i in range(len(abbreviations)):
    generatedData["candidate"] = Summary[abbreviations[i]]
    visualize.make_parallel_coordinate_matplot(generatedData[Summary[abbreviations[i]]!=-1], InsertApproach+str(abbreviations[i]), title=str(abbreviations[i]) + "" + title, applyLegend=False)
# Out:
# 250
# 100%|███████████████████████████████████████| 500/500 [00:00<00:00, 1155.21it/s]
# findfont: Font family ['Palatino Linotype'] not found. Falling back to DejaVu Sans.
# 250
# 100%|███████████████████████████████████████| 500/500 [00:00<00:00, 1478.37it/s]
# 250
# 100%|███████████████████████████████████████| 500/500 [00:00<00:00, 1938.21it/s]
# 250
# 100%|███████████████████████████████████████| 500/500 [00:00<00:00, 1806.40it/s]
