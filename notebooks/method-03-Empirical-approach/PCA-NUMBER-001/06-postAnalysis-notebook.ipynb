# %% [markdown]
# # 06-post-analysis
#
# How can we verify if the trained models are correct in their predictions?
#
# One way is to verify against known candidates.

# %%
import sys
sys.path.insert(0, "../")

import pandas as pd
from pathlib import Path
from src.visualization import visualize

data_dir = Path.cwd().parent.parent.parent / "data"
models_dir = Path.cwd().parent.parent.parent / "models" 

print("Current data directory {}".format(data_dir))

# Optional: Load the "autoreload" extension so that code can change
# %load_ext autoreload

#OPTIONAL: Always reload modules so that as you change code in src, it gets loaded
# %autoreload 2
# Out:
# Current data directory /Users/oliverhebnes/Documents/predicting-solid-state-qubit-material-hosts/data

# %%
known_candidates = ["SiC","SiGe", "C", "Si",
                         "GaN", "GaAs", "AlN", "ZnS", "ZnSe", "ZnO",
                         "AlP", "GaP", "AlAs", "ZnTe", "CdS"
                    ]
QD_2D_candidates = ["BN", "MoS2", "WSe2", "WS2",#2D
                    "InAs" #QD
                   ]

# %%
title = "Empirical summary"
InsertApproach = "03-empirical-approach"
numberOfPrincipalComponents = 176

# %% [markdown]
# ## Training set

# %%
trainingSet   = pd.read_pickle(data_dir / InsertApproach / "processed" / "trainingData.pkl")
trainingTarget   = pd.read_pickle(data_dir / InsertApproach / "processed" / "trainingTarget.pkl")
trainingSet["candidate"] = trainingTarget

# %%
trainingSet
# Out:
#     material_id  full_formula  AtomicOrbitals|HOMO_character  \
# 0         mp-24            C8                            2.0
# 1         mp-47            C4                            2.0
# 2         mp-66            C2                            2.0
# 3        mp-149           Si2                            2.0
# 4        mp-165           Si4                            2.0
# ..          ...           ...                            ...
# 585  mp-1275839  Co4Bi24S8O64                            3.0
# 586  mp-1291058  Sr4Mn2Mo2O12                            3.0
# 587  mp-1291630       Fe12O16                            3.0
# 588  mp-1298346     Sr8Co4O16                            3.0
# 589  mp-1539137      Rb1Cr5S8                            3.0
#
#      AtomicOrbitals|HOMO_element  AtomicOrbitals|HOMO_energy  \
# 0                              6                   -0.199186
# 1                              6                   -0.199186
# 2                              6                   -0.199186
# 3                             14                   -0.153293
# 4                             14                   -0.153293
# ..                           ...                         ...
# 585                           27                   -0.322368
# 586                           25                   -0.266540
# 587                           26                   -0.295049
# 588                           27                   -0.322368
# 589                           24                   -0.118123
#
#      AtomicOrbitals|LUMO_character  AtomicOrbitals|LUMO_element  \
# 0                              2.0                            6
# 1                              2.0                            6
# 2                              2.0                            6
# 3                              2.0                           14
# 4                              2.0                           14
# ..                             ...                          ...
# 585                            3.0                           27
# 586                            3.0                           25
# 587                            3.0                           26
# 588                            3.0                           27
# 589                            3.0                           24
#
#      AtomicOrbitals|LUMO_energy  \
# 0                     -0.199186
# 1                     -0.199186
# 2                     -0.199186
# 3                     -0.153293
# 4                     -0.153293
# ..                          ...
# 585                   -0.322368
# 586                   -0.266540
# 587                   -0.295049
# 588                   -0.322368
# 589                   -0.118123
#
#      AtomicPackingEfficiency|dist from 1 clusters |APE| < 0.010  \
# 0                                             1.000000
# 1                                             1.000000
# 2                                             1.000000
# 3                                             1.000000
# 4                                             1.000000
# ..                                                 ...
# 585                                           0.034641
# 586                                           0.052116
# 587                                           0.091832
# 588                                           0.057864
# 589                                           0.033111
#
#      AtomicPackingEfficiency|dist from 3 clusters |APE| < 0.010  ...  \
# 0                                             1.000000           ...
# 1                                             1.000000           ...
# 2                                             1.000000           ...
# 3                                             1.000000           ...
# 4                                             1.000000           ...
# ..                                                 ...           ...
# 585                                           0.052087           ...
# 586                                           0.058661           ...
# 587                                           0.135247           ...
# 588                                           0.095274           ...
# 589                                           0.074127           ...
#
#      AFLOWML|ml_agl_heat_capacity_Cv_300K_per_atom  \
# 0                                            0.634
# 1                                            0.588
# 2                                            0.617
# 3                                            2.577
# 4                                            2.549
# ..                                             ...
# 585                                          2.709
# 586                                          2.515
# 587                                          2.496
# 588                                          2.654
# 589                                          2.773
#
#      AFLOWML|ml_agl_thermal_conductivity_300K  \
# 0                                       3.043
# 1                                       3.223
# 2                                       4.279
# 3                                       3.417
# 4                                       3.443
# ..                                        ...
# 585                                     2.690
# 586                                     2.749
# 587                                     2.841
# 588                                     2.725
# 589                                     2.708
#
#      AFLOWML|ml_agl_thermal_expansion_300K  MP|spacegroup.number  \
# 0                                 0.000086                   206
# 1                                 0.000086                   194
# 2                                 0.000086                   227
# 3                                 0.000061                   227
# 4                                 0.000061                   194
# ..                                     ...                   ...
# 585                               0.000052                     3
# 586                               0.000060                     1
# 587                               0.000060                     5
# 588                               0.000061                     4
# 589                               0.000061                     8
#
#      MP|total_magnetization  MP|efermi   MP|Eg  AFLOWML|Eg  MP|Polar SG  \
# 0                  0.000000   9.783159  2.7785       3.355            0
# 1                  0.000000   9.983070  3.3395       3.166            0
# 2                  0.000000   9.614764  4.3387       3.593            0
# 3                  0.000000   5.564646  0.8527       0.742            0
# 4                  0.000000   5.891539  0.5139       0.667            0
# ..                      ...        ...     ...         ...          ...
# 585                0.000351   3.917413  2.3186       2.156            1
# 586                0.992766   3.987258  0.8079       0.000            1
# 587                6.504784   4.184540  0.1221       0.000            1
# 588                0.000485   2.323107  0.5907       0.000            1
# 589               11.000000   4.879709  0.3523       0.584            1
#
#      candidate
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# ..         ...
# 585        0.0
# 586        0.0
# 587        0.0
# 588        0.0
# 589        0.0
#
# [590 rows x 679 columns]

# %%
#trainingSet[["full_formula", "pretty_formula", "candidate"]][trainingSet["pretty_formula"].isin(known_candidates)]

# %% [markdown]
# ## Test set
# How many entries in our test set consists of known candidates?

# %%
Summary = pd.read_pickle(models_dir / InsertApproach /  "summary" / Path("PCA-" + str(numberOfPrincipalComponents) + "-" + "summary.pkl"))
Summary = Summary.reset_index(drop=True)
Summary.shape
# Out:
# (24544, 11)

# %%
Summary[Summary["pretty_formula"].isin(known_candidates)]
# Out:
#       material_id full_formula pretty_formula  LOG   LOG Prob  DT   DT Prob  \
# 15373   mp-630227          C60              C   1.0  0.778806  1.0      1.0
# 16130   mp-667273          C60              C   1.0  0.992246  0.0      0.0
# 16381   mp-680372          C60              C   1.0  0.761067  1.0      1.0
# 16456   mp-683919         C140              C   1.0  0.833887  1.0      1.0
# 21285  mp-1194362          C28              C   0.0  0.460855  1.0      1.0
# 22076  mp-1196583         C240              C   1.0  0.962119  0.0      0.0
# 24043  mp-1203645          C48              C   0.0  0.479805  1.0      1.0
# 24489  mp-1205417          C20              C   1.0  0.714762  1.0      1.0
#
#        RF    RF Prob  GB    GB Prob
# 15373  0.0  0.349925  1.0  0.837923
# 16130  1.0  0.606220  1.0  0.994849
# 16381  0.0  0.325475  1.0  0.840141
# 16456  0.0  0.361619  0.0  0.131179
# 21285  0.0  0.419586  0.0  0.018162
# 22076  0.0  0.368595  0.0  0.097529
# 24043  0.0  0.489372  0.0  0.040057
# 24489  0.0  0.377650  0.0  0.046767

# %%
Summary[Summary["pretty_formula"].isin(QD_2D_candidates)]
# Out:
#       material_id full_formula pretty_formula  LOG   LOG Prob  DT   DT Prob  \
# 45         mp-344         B4N4             BN   1.0  0.545369  1.0      1.0
# 239       mp-1599         B4N4             BN   0.0  0.178088  1.0      1.0
# 242       mp-1639         B1N1             BN   1.0  0.996963  1.0      1.0
# 386       mp-2653         B2N2             BN   1.0  0.995312  0.0      0.0
# 3088     mp-13151         B4N4             BN   1.0  0.939073  0.0      0.0
# 5148     mp-20305       In1As1           InAs   1.0  0.998013  1.0      1.0
# 15769   mp-644751         B4N4             BN   1.0  0.906148  1.0      1.0
# 19208  mp-1077506         B3N3             BN   0.0  0.484399  0.0      0.0
#
#        RF    RF Prob  GB    GB Prob
# 45     1.0  0.701941  1.0  0.811146
# 239    0.0  0.263452  0.0  0.145607
# 242    1.0  0.881510  1.0  0.999906
# 386    1.0  0.776191  1.0  0.999061
# 3088   1.0  0.725278  1.0  0.992772
# 5148   1.0  0.852749  1.0  0.999909
# 15769  1.0  0.511407  1.0  0.957099
# 19208  0.0  0.488820  0.0  0.162010

# %% [markdown]
# ## How many entries does the models agree on?

# %%
RF_DT_GB_LOG = Summary[(Summary["RF "] == 1) & 
                       (Summary["DT "] == 1) & 
                       (Summary["GB "] == 1) & 
                       (Summary["LOG "] == 1)]

RF_DT_GB_LOG.to_csv(models_dir / InsertApproach / "summary" / "RF_DT_GB_LOG.csv")
RF_DT_GB_LOG
# Out:
#       material_id full_formula pretty_formula  LOG   LOG Prob  DT   DT Prob  \
# 1            mp-7           S6              S   1.0  0.978347  1.0      1.0
# 2           mp-14          Se3             Se   1.0  0.996969  1.0      1.0
# 3           mp-19          Te3             Te   1.0  0.995230  1.0      1.0
# 4           mp-25           N8             N2   1.0  0.977147  1.0      1.0
# 8          mp-111          Ne1             Ne   1.0  0.999906  1.0      1.0
# ...           ...          ...            ...   ...       ...  ...      ...
# 22031  mp-1196461      C156F84          C13F7   1.0  0.569745  1.0      1.0
# 22067  mp-1196569  Mg17Si20O60   Mg17(SiO3)20   1.0  0.936560  1.0      1.0
# 22497  mp-1198022         Ge34             Ge   1.0  0.989959  1.0      1.0
# 24113  mp-1203927     Mo8N4O30       Mo4N2O15   1.0  0.532854  1.0      1.0
# 24147  mp-1204057     Si72O144           SiO2   1.0  0.993799  1.0      1.0
#
#        RF    RF Prob  GB    GB Prob
# 1      1.0  0.583934  1.0  0.998227
# 2      1.0  0.747606  1.0  0.999798
# 3      1.0  0.720981  1.0  0.999888
# 4      1.0  0.596804  1.0  0.957901
# 8      1.0  0.755679  1.0  0.999882
# ...    ...       ...  ...       ...
# 22031  1.0  0.613583  1.0  0.951376
# 22067  1.0  0.702011  1.0  0.998205
# 22497  1.0  0.773515  1.0  0.999805
# 24113  1.0  0.676001  1.0  0.936733
# 24147  1.0  0.746156  1.0  0.999776
#
# [214 rows x 11 columns]

# %%
Summary[(Summary["RF Prob"] > 0.8) & 
        (Summary["DT Prob"] > 0.8) & 
        (Summary["GB Prob"] > 0.8) & 
        (Summary["LOG Prob"] > 0.8)]
# Out:
#       material_id full_formula pretty_formula  LOG   LOG Prob  DT   DT Prob  \
# 10         mp-137         Ge12             Ge   1.0  0.984399  1.0      1.0
# 58         mp-406       Cd1Te1           CdTe   1.0  0.996856  1.0      1.0
# 119        mp-820       Hg1Se1           HgSe   1.0  0.990593  1.0      1.0
# 148       mp-1039       Mg2Te2           MgTe   1.0  0.963051  1.0      1.0
# 152       mp-1070       Cd2Se2           CdSe   1.0  0.988322  1.0      1.0
# 166       mp-1156       Ga1Sb1           GaSb   1.0  0.996969  1.0      1.0
# 241       mp-1634       Mo2Se4          MoSe2   1.0  0.957531  1.0      1.0
# 242       mp-1639         B1N1             BN   1.0  0.996963  1.0      1.0
# 279       mp-1876        Sn1S1            SnS   1.0  0.949432  1.0      1.0
# 281       mp-1883       Sn1Te1           SnTe   1.0  0.985865  1.0      1.0
# 391       mp-2691       Cd1Se1           CdSe   1.0  0.993839  1.0      1.0
# 392       mp-2693       Sn1Se1           SnSe   1.0  0.966586  1.0      1.0
# 684       mp-3829    Cd2Sn2As4        CdSnAs2   1.0  0.989417  1.0      1.0
# 688       mp-3839    Ga2Cu2Te4        GaCuTe2   1.0  0.850476  1.0      1.0
# 1061      mp-5213     Cd2Sn2P4         CdSnP2   1.0  0.872792  1.0      1.0
# 2596     mp-10013        Sn1S1            SnS   1.0  0.992360  1.0      1.0
# 2723     mp-10759       Ge1Se1           GeSe   1.0  0.920501  1.0      1.0
# 3020     mp-12779       Cd2Te2           CdTe   1.0  0.994487  1.0      1.0
# 3064     mp-13031       Mg1Se1           MgSe   1.0  0.908606  1.0      1.0
# 5148     mp-20305       In1As1           InAs   1.0  0.998013  1.0      1.0
# 5156     mp-20351        In1P1            InP   1.0  0.963405  1.0      1.0
# 5186     mp-20554    In2Ag2Se4        InAgSe2   1.0  0.937716  1.0      1.0
# 5601     mp-22895        Cu1I1            CuI   1.0  0.957926  1.0      1.0
# 5613     mp-22913       Cu1Br1           CuBr   1.0  0.983070  1.0      1.0
# 5620     mp-22925        Ag1I1            AgI   1.0  0.987055  1.0      1.0
# 5793     mp-23197        Tl1I1            TlI   1.0  0.867096  1.0      1.0
# 5814     mp-23231       Ag1Br1           AgBr   1.0  0.888522  1.0      1.0
# 14089   mp-569346        Cu2I2            CuI   1.0  0.945674  1.0      1.0
# 15369   mp-629458       B1C2N1           BC2N   1.0  0.992873  1.0      1.0
# 18514   mp-966800        In2P2            InP   1.0  0.983577  1.0      1.0
# 18711  mp-1007776        Tl1P1            TlP   1.0  0.970705  1.0      1.0
# 18720  mp-1008523       B1C2N1           BC2N   1.0  0.997155  1.0      1.0
# 18725  mp-1008559         B2P2             BP   1.0  0.985703  1.0      1.0
# 18742  mp-1009540        Os1C1            OsC   1.0  0.929464  1.0      1.0
# 18754  mp-1009813       Si1Sn1           SiSn   1.0  0.992963  1.0      1.0
# 18788  mp-1018040       Mg2Se2           MgSe   1.0  0.928385  1.0      1.0
# 19281  mp-1078597    Zn1Cd3Se4       ZnCd3Se4   1.0  0.961226  1.0      1.0
# 19358  mp-1079201       B2C4N2           BC2N   1.0  0.976994  1.0      1.0
#
#        RF    RF Prob  GB    GB Prob
# 10     1.0  0.820225  1.0  0.999224
# 58     1.0  0.810443  1.0  0.998180
# 119    1.0  0.810698  1.0  0.999414
# 148    1.0  0.807211  1.0  0.998426
# 152    1.0  0.940534  1.0  0.999909
# 166    1.0  0.841507  1.0  0.999909
# 241    1.0  0.828817  1.0  0.993235
# 242    1.0  0.881510  1.0  0.999906
# 279    1.0  0.802371  1.0  0.999501
# 281    1.0  0.801184  1.0  0.997375
# 391    1.0  0.906538  1.0  0.999793
# 392    1.0  0.803499  1.0  0.999415
# 684    1.0  0.840369  1.0  0.999909
# 688    1.0  0.828060  1.0  0.997559
# 1061   1.0  0.814840  1.0  0.999755
# 2596   1.0  0.806281  1.0  0.999614
# 2723   1.0  0.833296  1.0  0.999365
# 3020   1.0  0.840305  1.0  0.998882
# 3064   1.0  0.835565  1.0  0.997910
# 5148   1.0  0.852749  1.0  0.999909
# 5156   1.0  0.845184  1.0  0.999755
# 5186   1.0  0.841712  1.0  0.999909
# 5601   1.0  0.890446  1.0  0.999199
# 5613   1.0  0.837758  1.0  0.999865
# 5620   1.0  0.802621  1.0  0.998827
# 5793   1.0  0.817349  1.0  0.999432
# 5814   1.0  0.810716  1.0  0.999248
# 14089  1.0  0.878424  1.0  0.999200
# 15369  1.0  0.898982  1.0  0.999906
# 18514  1.0  0.824100  1.0  0.999817
# 18711  1.0  0.837922  1.0  0.999817
# 18720  1.0  0.883297  1.0  0.999906
# 18725  1.0  0.800790  1.0  0.999730
# 18742  1.0  0.821314  1.0  0.999875
# 18754  1.0  0.816576  1.0  0.999753
# 18788  1.0  0.801772  1.0  0.997910
# 19281  1.0  0.856915  1.0  0.999878
# 19358  1.0  0.805965  1.0  0.996854

# %%
RF_DT_GB = Summary[(Summary["RF "] == 1) & 
                       (Summary["DT "] == 1) & 
                       (Summary["GB "] == 1)]

RF_DT_GB.to_csv(models_dir / InsertApproach / "summary" / "RF_DT_GB.csv")
RF_DT_GB
# Out:
#       material_id     full_formula     pretty_formula  LOG   LOG Prob  DT   \
# 1            mp-7               S6                  S   1.0  0.978347  1.0
# 2           mp-14              Se3                 Se   1.0  0.996969  1.0
# 3           mp-19              Te3                 Te   1.0  0.995230  1.0
# 4           mp-25               N8                 N2   1.0  0.977147  1.0
# 8          mp-111              Ne1                 Ne   1.0  0.999906  1.0
# ...           ...              ...                ...   ...       ...  ...
# 22939  mp-1199624  Ba16Na8Nb40O120        Ba2NaNb5O15   0.0  0.199765  1.0
# 24113  mp-1203927         Mo8N4O30           Mo4N2O15   1.0  0.532854  1.0
# 24147  mp-1204057         Si72O144               SiO2   1.0  0.993799  1.0
# 24186  mp-1204230     Sr64Ga32O112           Sr4Ga2O7   0.0  0.017915  1.0
# 24253  mp-1204533  Mg45Si32H58O138  Mg45Si32(H29O69)2   0.0  0.186058  1.0
#
#        DT Prob  RF    RF Prob  GB    GB Prob
# 1          1.0  1.0  0.583934  1.0  0.998227
# 2          1.0  1.0  0.747606  1.0  0.999798
# 3          1.0  1.0  0.720981  1.0  0.999888
# 4          1.0  1.0  0.596804  1.0  0.957901
# 8          1.0  1.0  0.755679  1.0  0.999882
# ...        ...  ...       ...  ...       ...
# 22939      1.0  1.0  0.652657  1.0  0.999729
# 24113      1.0  1.0  0.676001  1.0  0.936733
# 24147      1.0  1.0  0.746156  1.0  0.999776
# 24186      1.0  1.0  0.682370  1.0  0.998106
# 24253      1.0  1.0  0.671189  1.0  0.998777
#
# [262 rows x 11 columns]

# %%
Summary[(Summary["RF Prob"] > 0.75) & 
        (Summary["DT Prob"] > 0.75) & 
        (Summary["GB Prob"] > 0.75)]
# Out:
#       material_id full_formula pretty_formula  LOG   LOG Prob  DT   DT Prob  \
# 8          mp-111          Ne1             Ne   1.0  0.999906  1.0      1.0
# 10         mp-137         Ge12             Ge   1.0  0.984399  1.0      1.0
# 34         mp-286       Yb1Se1           YbSe   1.0  0.710996  1.0      1.0
# 58         mp-406       Cd1Te1           CdTe   1.0  0.996856  1.0      1.0
# 119        mp-820       Hg1Se1           HgSe   1.0  0.990593  1.0      1.0
# ...           ...          ...            ...   ...       ...  ...      ...
# 19145  mp-1067619          Ge4             Ge   1.0  0.998346  1.0      1.0
# 19193  mp-1072429       Ga4Ru2          Ga2Ru   1.0  0.974413  1.0      1.0
# 19281  mp-1078597    Zn1Cd3Se4       ZnCd3Se4   1.0  0.961226  1.0      1.0
# 19358  mp-1079201       B2C4N2           BC2N   1.0  0.976994  1.0      1.0
# 22497  mp-1198022         Ge34             Ge   1.0  0.989959  1.0      1.0
#
#        RF    RF Prob  GB    GB Prob
# 8      1.0  0.755679  1.0  0.999882
# 10     1.0  0.820225  1.0  0.999224
# 34     1.0  0.809138  1.0  0.998406
# 58     1.0  0.810443  1.0  0.998180
# 119    1.0  0.810698  1.0  0.999414
# ...    ...       ...  ...       ...
# 19145  1.0  0.766923  1.0  0.999890
# 19193  1.0  0.771691  1.0  0.999902
# 19281  1.0  0.856915  1.0  0.999878
# 19358  1.0  0.805965  1.0  0.996854
# 22497  1.0  0.773515  1.0  0.999805
#
# [73 rows x 11 columns]

# %%
Summary[(Summary["RF "] == 1) &  
        (Summary["GB "] == 1)]
# Out:
#       material_id     full_formula     pretty_formula  LOG   LOG Prob  DT   \
# 1            mp-7               S6                  S   1.0  0.978347  1.0
# 2           mp-14              Se3                 Se   1.0  0.996969  1.0
# 3           mp-19              Te3                 Te   1.0  0.995230  1.0
# 4           mp-25               N8                 N2   1.0  0.977147  1.0
# 8          mp-111              Ne1                 Ne   1.0  0.999906  1.0
# ...           ...              ...                ...   ...       ...  ...
# 22939  mp-1199624  Ba16Na8Nb40O120        Ba2NaNb5O15   0.0  0.199765  1.0
# 24113  mp-1203927         Mo8N4O30           Mo4N2O15   1.0  0.532854  1.0
# 24147  mp-1204057         Si72O144               SiO2   1.0  0.993799  1.0
# 24186  mp-1204230     Sr64Ga32O112           Sr4Ga2O7   0.0  0.017915  1.0
# 24253  mp-1204533  Mg45Si32H58O138  Mg45Si32(H29O69)2   0.0  0.186058  1.0
#
#        DT Prob  RF    RF Prob  GB    GB Prob
# 1          1.0  1.0  0.583934  1.0  0.998227
# 2          1.0  1.0  0.747606  1.0  0.999798
# 3          1.0  1.0  0.720981  1.0  0.999888
# 4          1.0  1.0  0.596804  1.0  0.957901
# 8          1.0  1.0  0.755679  1.0  0.999882
# ...        ...  ...       ...  ...       ...
# 22939      1.0  1.0  0.652657  1.0  0.999729
# 24113      1.0  1.0  0.676001  1.0  0.936733
# 24147      1.0  1.0  0.746156  1.0  0.999776
# 24186      1.0  1.0  0.682370  1.0  0.998106
# 24253      1.0  1.0  0.671189  1.0  0.998777
#
# [395 rows x 11 columns]

# %%
Summary[Summary["LOG "]==1]
# Out:
#       material_id full_formula pretty_formula  LOG   LOG Prob  DT   DT Prob  \
# 1            mp-7           S6              S   1.0  0.978347  1.0      1.0
# 2           mp-14          Se3             Se   1.0  0.996969  1.0      1.0
# 3           mp-19          Te3             Te   1.0  0.995230  1.0      1.0
# 4           mp-25           N8             N2   1.0  0.977147  1.0      1.0
# 5           mp-77          S32              S   1.0  0.907468  0.0      0.0
# ...           ...          ...            ...   ...       ...  ...      ...
# 23632  mp-1202132    Sr5Ti7O19      Sr5Ti7O19   1.0  1.000000  0.0      0.0
# 24075  mp-1203760     Si28Tc16         Si7Tc4   1.0  0.838841  1.0      1.0
# 24113  mp-1203927     Mo8N4O30       Mo4N2O15   1.0  0.532854  1.0      1.0
# 24147  mp-1204057     Si72O144           SiO2   1.0  0.993799  1.0      1.0
# 24489  mp-1205417          C20              C   1.0  0.714762  1.0      1.0
#
#        RF    RF Prob  GB    GB Prob
# 1      1.0  0.583934  1.0  0.998227
# 2      1.0  0.747606  1.0  0.999798
# 3      1.0  0.720981  1.0  0.999888
# 4      1.0  0.596804  1.0  0.957901
# 5      0.0  0.371349  1.0  0.978307
# ...    ...       ...  ...       ...
# 23632  1.0  0.538529  0.0  0.031775
# 24075  0.0  0.483934  1.0  0.751266
# 24113  1.0  0.676001  1.0  0.936733
# 24147  1.0  0.746156  1.0  0.999776
# 24489  0.0  0.377650  0.0  0.046767
#
# [842 rows x 11 columns]

# %%
generatedData = pd.read_pickle(data_dir / "interim" / "featurized" / "featurized-11-04-2021.pkl")
generatedData = generatedData[~generatedData["material_id"].isin(trainingSet["material_id"])].reset_index(drop=True)

# %%
visualize.visualize_heatmap_of_combinations(Summary)
# Out:
# findfont: Font family ['Palatino Linotype'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Palatino Linotype'] not found. Falling back to DejaVu Sans.
# [1.0, 0.2623224728487886, 0.1921470342522974, 0.17878028404344193, 0.29741019214703424, 0.23391812865497075, 0.662751677852349, 1.0, 1.0, 0.5213776722090261, 0.4750593824228028]
#                   LOG LOG LOG LOG   LOG LOG LOG DT   LOG LOG RF DT   \
# LOG LOG LOG LOG                1.0         0.262322        0.192147
# LOG LOG LOG DT                 1.0         0.262322        0.192147
# LOG LOG RF DT                  1.0         0.262322        0.192147
# LOG RF GB DT                   1.0         0.262322        0.192147
# DT GB DT DT                    1.0         0.262322        0.192147
# DT RF DT DT                    1.0         0.262322        0.192147
# RF RF GB GB                    1.0         0.262322        0.192147
# RF RF RF RF                    1.0         0.262322        0.192147
# GB GB GB GB                    1.0         0.262322        0.192147
# GB LOG LOG LOG                 1.0         0.262322        0.192147
# RF LOG LOG LOG                 1.0         0.262322        0.192147
#
#                   LOG RF GB DT   DT GB DT DT   DT RF DT DT   RF RF GB GB   \
# LOG LOG LOG LOG         0.17878       0.29741      0.233918      0.662752
# LOG LOG LOG DT          0.17878       0.29741      0.233918      0.662752
# LOG LOG RF DT           0.17878       0.29741      0.233918      0.662752
# LOG RF GB DT            0.17878       0.29741      0.233918      0.662752
# DT GB DT DT             0.17878       0.29741      0.233918      0.662752
# DT RF DT DT             0.17878       0.29741      0.233918      0.662752
# RF RF GB GB             0.17878       0.29741      0.233918      0.662752
# RF RF RF RF             0.17878       0.29741      0.233918      0.662752
# GB GB GB GB             0.17878       0.29741      0.233918      0.662752
# GB LOG LOG LOG          0.17878       0.29741      0.233918      0.662752
# RF LOG LOG LOG          0.17878       0.29741      0.233918      0.662752
#
#                   RF RF RF RF   GB GB GB GB   GB LOG LOG LOG   RF LOG LOG LOG
# LOG LOG LOG LOG            1.0           1.0         0.521378         0.475059
# LOG LOG LOG DT             1.0           1.0         0.521378         0.475059
# LOG LOG RF DT              1.0           1.0         0.521378         0.475059
# LOG RF GB DT               1.0           1.0         0.521378         0.475059
# DT GB DT DT                1.0           1.0         0.521378         0.475059
# DT RF DT DT                1.0           1.0         0.521378         0.475059
# RF RF GB GB                1.0           1.0         0.521378         0.475059
# RF RF RF RF                1.0           1.0         0.521378         0.475059
# GB GB GB GB                1.0           1.0         0.521378         0.475059
# GB LOG LOG LOG             1.0           1.0         0.521378         0.475059
# RF LOG LOG LOG             1.0           1.0         0.521378         0.475059

# %%
Summary = Summary[Summary["material_id"].isin(generatedData.material_id)].reset_index(drop=True)
generatedData = generatedData[generatedData["material_id"].isin(Summary.material_id)].reset_index(drop=True)
abbreviations = ["LOG ", "DT ", "RF ", "GB "]
for i in range(len(abbreviations)):
    generatedData["candidate"] = Summary[abbreviations[i]]
    visualize.make_parallel_coordinate_matplot(generatedData[Summary[abbreviations[i]]!=-1], InsertApproach+str(abbreviations[i]), title=str(abbreviations[i]) + "" + title, applyLegend=False)
# Out:
# 250
# 100%|███████████████████████████████████████| 500/500 [00:00<00:00, 1018.47it/s]
# findfont: Font family ['Palatino Linotype'] not found. Falling back to DejaVu Sans.
# 250
# 100%|███████████████████████████████████████| 500/500 [00:00<00:00, 1971.46it/s]
# 250
# 100%|███████████████████████████████████████| 500/500 [00:00<00:00, 1674.90it/s]
# 250
# 100%|███████████████████████████████████████| 500/500 [00:00<00:00, 1683.26it/s]
